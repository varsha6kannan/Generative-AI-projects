# %% [markdown]
# # Project FinBot

# %% [markdown]
# ### How does FinBot help?

# %% [markdown]
# On a daily basis there are many news articles that come about based on the stock market. A user may find it time consuming to read all the articles, hence gets overwhelmed. FinBot helps to ingest all the articles you like to know more about and the user can perform RAG search with FinBot.

# %% [markdown]
# #### STEP 1: Importing the required libraries

# %%
from langchain.chains import RetrievalQAWithSourcesChain
from langchain.chains.qa_with_sources.loading import load_qa_with_sources_chain
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.document_loaders import UnstructuredURLLoader
from langchain.embeddings import OpenAIEmbeddings
from langchain.vectorstores import FAISS
import os
import time
import langchain
from langchain import OpenAI

# %%
# read the openai api key
os.environ["OPENAI_API_KEY"]=open("OPENAI_API_Key.txt","r").read().strip()

# %% [markdown]
# #### STEP 2: Load the data from the URLS

# %% [markdown]
# Loading the urls of the fintech news websites using the library from langChain called unstructured

# %%
# !pip install unstructured
# Out:
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Collecting unstructured
#   Using cached unstructured-0.16.23-py3-none-any.whl.metadata (24 kB)
# Collecting chardet (from unstructured)
#   Using cached chardet-5.2.0-py3-none-any.whl.metadata (3.4 kB)
# Requirement already satisfied: filetype in c:\users\varsha kannan\appdata\local\programs\python\python312\lib\site-packages (from unstructured) (1.2.0)
# Collecting python-magic (from unstructured)
#   Downloading python_magic-0.4.27-py2.py3-none-any.whl.metadata (5.8 kB)
# Collecting lxml (from unstructured)
#   Downloading lxml-5.3.1-cp312-cp312-win_amd64.whl.metadata (3.8 kB)
# Requirement already satisfied: nltk in c:\users\varsha kannan\appdata\local\programs\python\python312\lib\site-packages (from unstructured) (3.9.1)
# Requirement already satisfied: requests in c:\users\varsha kannan\appdata\local\programs\python\python312\lib\site-packages (from unstructured) (2.32.3)
# Requirement already satisfied: beautifulsoup4 in c:\users\varsha kannan\appdata\local\programs\python\python312\lib\site-packages (from unstructured) (4.12.3)
# Collecting emoji (from unstructured)
#   Using cached emoji-2.14.1-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: dataclasses-json in c:\users\varsha kannan\appdata\local\programs\python\python312\lib\site-packages (from unstructured) (0.6.7)
# Collecting python-iso639 (from unstructured)
#   Downloading python_iso639-2025.2.18-py3-none-any.whl.metadata (14 kB)
# Collecting langdetect (from unstructured)
#   Downloading langdetect-1.0.9.tar.gz (981 kB)
#      ---------------------------------------- 0.0/981.5 kB ? eta -:--:--
#      -------------------------------------- 981.5/981.5 kB 9.2 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting numpy<2 (from unstructured)
#   Downloading numpy-1.26.4-cp312-cp312-win_amd64.whl.metadata (61 kB)
# Collecting rapidfuzz (from unstructured)
#   Downloading rapidfuzz-3.12.1-cp312-cp312-win_amd64.whl.metadata (11 kB)
# Requirement already satisfied: backoff in c:\users\varsha kannan\appdata\local\programs\python\python312\lib\site-packages (from unstructured) (2.2.1)
# Requirement already satisfied: typing-extensions in c:\users\varsha kannan\appdata\local\programs\python\python312\lib\site-packages (from unstructured) (4.12.2)
# Collecting unstructured-client (from unstructured)
#   Using cached unstructured_client-0.30.6-py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: wrapt in c:\users\varsha kannan\appdata\local\programs\python\python312\lib\site-packages (from unstructured) (1.17.2)
# Requirement already satisfied: tqdm in c:\users\varsha kannan\appdata\local\programs\python\python312\lib\site-packages (from unstructured) (4.67.1)
# Requirement already satisfied: psutil in c:\users\varsha kannan\appdata\roaming\python\python312\site-packages (from unstructured) (6.1.1)
# Collecting python-oxmsg (from unstructured)
#   Using cached python_oxmsg-0.0.2-py3-none-any.whl.metadata (5.0 kB)
# Collecting html5lib (from unstructured)
#   Downloading html5lib-1.1-py2.py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: soupsieve>1.2 in c:\users\varsha kannan\appdata\local\programs\python\python312\lib\site-packages (from beautifulsoup4->unstructured) (2.6)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\varsha kannan\appdata\local\programs\python\python312\lib\site-packages (from dataclasses-json->unstructured) (3.26.0)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\varsha kannan\appdata\local\programs\python\python312\lib\site-packages (from dataclasses-json->unstructured) (0.9.0)
# Requirement already satisfied: six>=1.9 in c:\users\varsha kannan\appdata\local\programs\python\python312\lib\site-packages (from html5lib->unstructured) (1.17.0)
# Collecting webencodings (from html5lib->unstructured)
#   Downloading webencodings-0.5.1-py2.py3-none-any.whl.metadata (2.1 kB)
# Requirement already satisfied: click in c:\users\varsha kannan\appdata\local\programs\python\python312\lib\site-packages (from nltk->unstructured) (8.1.8)
# Requirement already satisfied: joblib in c:\users\varsha kannan\appdata\local\programs\python\python312\lib\site-packages (from nltk->unstructured) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\varsha kannan\appdata\local\programs\python\python312\lib\site-packages (from nltk->unstructured) (2024.11.6)
# Collecting olefile (from python-oxmsg->unstructured)
#   Using cached olefile-0.47-py2.py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\varsha kannan\appdata\local\programs\python\python312\lib\site-packages (from requests->unstructured) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\varsha kannan\appdata\local\programs\python\python312\lib\site-packages (from requests->unstructured) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\varsha kannan\appdata\local\programs\python\python312\lib\site-packages (from requests->unstructured) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\varsha kannan\appdata\local\programs\python\python312\lib\site-packages (from requests->unstructured) (2024.12.14)
# Requirement already satisfied: colorama in c:\users\varsha kannan\appdata\local\programs\python\python312\lib\site-packages (from tqdm->unstructured) (0.4.6)
# Collecting aiofiles>=24.1.0 (from unstructured-client->unstructured)
#   Using cached aiofiles-24.1.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: cryptography>=3.1 in c:\users\varsha kannan\appdata\local\programs\python\python312\lib\site-packages (from unstructured-client->unstructured) (44.0.0)
# Collecting eval-type-backport>=0.2.0 (from unstructured-client->unstructured)
#   Downloading eval_type_backport-0.2.2-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: httpx>=0.27.0 in c:\users\varsha kannan\appdata\local\programs\python\python312\lib\site-packages (from unstructured-client->unstructured) (0.27.2)
# Requirement already satisfied: nest-asyncio>=1.6.0 in c:\users\varsha kannan\appdata\roaming\python\python312\site-packages (from unstructured-client->unstructured) (1.6.0)
# Requirement already satisfied: pydantic>=2.10.3 in c:\users\varsha kannan\appdata\local\programs\python\python312\lib\site-packages (from unstructured-client->unstructured) (2.10.6)
# Requirement already satisfied: pypdf>=4.0 in c:\users\varsha kannan\appdata\local\programs\python\python312\lib\site-packages (from unstructured-client->unstructured) (5.2.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\varsha kannan\appdata\local\programs\python\python312\lib\site-packages (from unstructured-client->unstructured) (2.9.0.post0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\varsha kannan\appdata\local\programs\python\python312\lib\site-packages (from unstructured-client->unstructured) (1.0.0)
# Requirement already satisfied: cffi>=1.12 in c:\users\varsha kannan\appdata\local\programs\python\python312\lib\site-packages (from cryptography>=3.1->unstructured-client->unstructured) (1.17.1)
# Requirement already satisfied: anyio in c:\users\varsha kannan\appdata\local\programs\python\python312\lib\site-packages (from httpx>=0.27.0->unstructured-client->unstructured) (4.8.0)
# Requirement already satisfied: httpcore==1.* in c:\users\varsha kannan\appdata\local\programs\python\python312\lib\site-packages (from httpx>=0.27.0->unstructured-client->unstructured) (1.0.7)
# Requirement already satisfied: sniffio in c:\users\varsha kannan\appdata\local\programs\python\python312\lib\site-packages (from httpx>=0.27.0->unstructured-client->unstructured) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\varsha kannan\appdata\local\programs\python\python312\lib\site-packages (from httpcore==1.*->httpx>=0.27.0->unstructured-client->unstructured) (0.14.0)
# Requirement already satisfied: packaging>=17.0 in c:\users\varsha kannan\appdata\local\programs\python\python312\lib\site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->unstructured) (24.2)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\varsha kannan\appdata\local\programs\python\python312\lib\site-packages (from pydantic>=2.10.3->unstructured-client->unstructured) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in c:\users\varsha kannan\appdata\local\programs\python\python312\lib\site-packages (from pydantic>=2.10.3->unstructured-client->unstructured) (2.27.2)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\varsha kannan\appdata\local\programs\python\python312\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json->unstructured) (1.0.0)
# Requirement already satisfied: pycparser in c:\users\varsha kannan\appdata\local\programs\python\python312\lib\site-packages (from cffi>=1.12->cryptography>=3.1->unstructured-client->unstructured) (2.22)
# Using cached unstructured-0.16.23-py3-none-any.whl (1.8 MB)
# Downloading numpy-1.26.4-cp312-cp312-win_amd64.whl (15.5 MB)
#    ---------------------------------------- 0.0/15.5 MB ? eta -:--:--
#    ---- ----------------------------------- 1.8/15.5 MB 9.1 MB/s eta 0:00:02
#    ---------- ----------------------------- 3.9/15.5 MB 9.4 MB/s eta 0:00:02
#    ------------- -------------------------- 5.2/15.5 MB 9.1 MB/s eta 0:00:02
#    --------------- ------------------------ 6.0/15.5 MB 7.5 MB/s eta 0:00:02
#    ---------------- ----------------------- 6.6/15.5 MB 6.4 MB/s eta 0:00:02
#    ------------------ --------------------- 7.1/15.5 MB 5.7 MB/s eta 0:00:02
#    ------------------- -------------------- 7.6/15.5 MB 5.5 MB/s eta 0:00:02
#    --------------------- ------------------ 8.4/15.5 MB 5.1 MB/s eta 0:00:02
#    ------------------------ --------------- 9.4/15.5 MB 5.1 MB/s eta 0:00:02
#    --------------------------- ------------ 10.5/15.5 MB 5.2 MB/s eta 0:00:01
#    ------------------------------ --------- 11.8/15.5 MB 5.3 MB/s eta 0:00:01
#    --------------------------------- ------ 13.1/15.5 MB 5.3 MB/s eta 0:00:01
#    ----------------------------------- ---- 13.9/15.5 MB 5.3 MB/s eta 0:00:01
#    ------------------------------------- -- 14.7/15.5 MB 5.2 MB/s eta 0:00:01
#    ---------------------------------------- 15.5/15.5 MB 5.1 MB/s eta 0:00:00
# Downloading chardet-5.2.0-py3-none-any.whl (199 kB)
# Using cached emoji-2.14.1-py3-none-any.whl (590 kB)
# Downloading html5lib-1.1-py2.py3-none-any.whl (112 kB)
# Downloading lxml-5.3.1-cp312-cp312-win_amd64.whl (3.8 MB)
#    ---------------------------------------- 0.0/3.8 MB ? eta -:--:--
#    ----- ---------------------------------- 0.5/3.8 MB 2.8 MB/s eta 0:00:02
#    ---------- ----------------------------- 1.0/3.8 MB 3.0 MB/s eta 0:00:01
#    ---------------- ----------------------- 1.6/3.8 MB 3.0 MB/s eta 0:00:01
#    ------------------------ --------------- 2.4/3.8 MB 3.0 MB/s eta 0:00:01
#    ------------------------------ --------- 2.9/3.8 MB 3.1 MB/s eta 0:00:01
#    ----------------------------------- ---- 3.4/3.8 MB 3.1 MB/s eta 0:00:01
#    -------------------------------------- - 3.7/3.8 MB 2.9 MB/s eta 0:00:01
#    ---------------------------------------- 3.8/3.8 MB 2.6 MB/s eta 0:00:00
# Downloading python_iso639-2025.2.18-py3-none-any.whl (167 kB)
# Downloading python_magic-0.4.27-py2.py3-none-any.whl (13 kB)
# Using cached python_oxmsg-0.0.2-py3-none-any.whl (31 kB)
# Downloading rapidfuzz-3.12.1-cp312-cp312-win_amd64.whl (1.6 MB)
#    ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#    ------ --------------------------------- 0.3/1.6 MB ? eta -:--:--
#    ------ --------------------------------- 0.3/1.6 MB ? eta -:--:--
#    ------------- -------------------------- 0.5/1.6 MB 985.5 kB/s eta 0:00:02
#    ------------------- -------------------- 0.8/1.6 MB 987.4 kB/s eta 0:00:01
#    -------------------------- ------------- 1.0/1.6 MB 1.1 MB/s eta 0:00:01
#    -------------------------------- ------- 1.3/1.6 MB 1.1 MB/s eta 0:00:01
#    ---------------------------------------- 1.6/1.6 MB 1.2 MB/s eta 0:00:00
# Downloading unstructured_client-0.30.6-py3-none-any.whl (166 kB)
# Using cached aiofiles-24.1.0-py3-none-any.whl (15 kB)
# Downloading eval_type_backport-0.2.2-py3-none-any.whl (5.8 kB)
# Using cached olefile-0.47-py2.py3-none-any.whl (114 kB)
# Downloading webencodings-0.5.1-py2.py3-none-any.whl (11 kB)
# Building wheels for collected packages: langdetect
#   Building wheel for langdetect (pyproject.toml): started
#   Building wheel for langdetect (pyproject.toml): finished with status 'done'
#   Created wheel for langdetect: filename=langdetect-1.0.9-py3-none-any.whl size=993313 sha256=2aa04b8e95209453d21b508f2a91d2bf7ad6bc496775aa0ddfafc0c325a55a94
#   Stored in directory: c:\users\varsha kannan\appdata\local\pip\cache\wheels\c1\67\88\e844b5b022812e15a52e4eaa38a1e709e99f06f6639d7e3ba7
# Successfully built langdetect
# Installing collected packages: webencodings, rapidfuzz, python-magic, python-iso639, olefile, numpy, lxml, langdetect, html5lib, eval-type-backport, emoji, chardet, aiofiles, python-oxmsg, unstructured-client, unstructured
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.2.2
#     Uninstalling numpy-2.2.2:
#       Successfully uninstalled numpy-2.2.2
# Successfully installed aiofiles-24.1.0 chardet-5.2.0 emoji-2.14.1 eval-type-backport-0.2.2 html5lib-1.1 langdetect-1.0.9 lxml-5.3.1 numpy-1.26.4 olefile-0.47 python-iso639-2025.2.18 python-magic-0.4.27 python-oxmsg-0.0.2 rapidfuzz-3.12.1 unstructured-0.16.23 unstructured-client-0.30.6 webencodings-0.5.1

# %% [markdown]
# As of date today-> 28/02/2025
# these articles on Stock market are on trend based on stock market crash:
# - https://indianexpress.com/article/business/market/stock-market-crash-today-sensex-nifty-live-updates-9860683/
# - https://www.ndtvprofit.com/markets/february-market-fallout-niftys-longest-losing-streak-since-1996-and-fmcgs-worst-fall-in-18-years
# - https://economictimes.indiatimes.com/markets/stocks/stock-watch/sensex-falls-but-these-stocks-gained-over-10-on-bse/articleshow/118628952.cms
# - https://economictimes.indiatimes.com/markets/stocks/stock-watch/stock-market-update-stocks-that-hit-52-week-highs-on-nse-in-todays-trade/articleshow/118628856.cms
# - https://www.thehindu.com/business/markets/rupee-falls-28-paise-to-close-at-8746-against-us-dollar/article69274471.ece

# %%
loader=UnstructuredURLLoader(
urls = [
       " https://indianexpress.com/article/business/market/stock-market-crash-today-sensex-nifty-live-updates-9860683/",
       " https://www.ndtvprofit.com/markets/february-market-fallout-niftys-longest-losing-streak-since-1996-and-fmcgs-worst-fall-in-18-years",
       " https://economictimes.indiatimes.com/markets/stocks/stock-watch/sensex-falls-but-these-stocks-gained-over-10-on-bse/articleshow/118628952.cms",
       " https://economictimes.indiatimes.com/markets/stocks/stock-watch/stock-market-update-stocks-that-hit-52-week-highs-on-nse-in-todays-trade/articleshow/118628856.cms",
       " https://www.thehindu.com/business/markets/rupee-falls-28-paise-to-close-at-8746-against-us-dollar/article69274471.ece"
    ]
)

# %%
data=loader.load()
print("Number of documents loaded: ", len(data))
# Out:
# Number of documents loaded:  5

# %%
data[4].page_content
# Out:
# "February 28, 2025e-Paper\n\nSubscribe\n\nLive Now Agriculture\n\nBooks\n\nBooks\n\nHindi Belt\n\nThe Hindu On Books Books of the week, reviews, excerpts, new titles and features.\n\nSEE ALL NEWSLETTERS\n\nBusiness\n\nBusiness Agri-Business Economy Industry Markets Budget\n\nChildren\n\nCities\n\nCities Bengaluru Chennai Coimbatore Delhi Hyderabad Kochi Kolkata Kozhikode Madurai Mangaluru Mumbai Puducherry Thiruvananthapuram Tiruchirapalli Vijayawada Visakhapatnam\n\nData\n\nData\n\nData Point Podcast\n\nData Point Decoding the headlines with facts, figures, and numbers\n\nSEE ALL NEWSLETTERS\n\nEbook\n\nEducation\n\nEducation Careers Colleges Schools\n\nElections\n\nEntertainment\n\nEntertainment Art Dance Movies Music Reviews Theatre\n\nFirst Day First Show News and reviews from the world of cinema and streaming.\n\nSEE ALL NEWSLETTERS\n\nEnvironment\n\nFood\n\nFood Dining Features Guides Recipes\n\nGood Health Hunting\n\nHealth\n\nHealth\n\nMonkeypox\n\nHealth Matters Ramya Kannan writes to you on getting to good health, and staying there\n\nSEE ALL NEWSLETTERS\n\nLife & Style\n\nLife & Style Fashion Fitness Homes and gardens Luxury Motoring Travel\n\nNews\n\nNews India World States Cities\n\nGround Zero Spotlight\n\nThe View From India Looking at World Affairs from the Indian perspective.\n\nSEE ALL NEWSLETTERS\n\nOpinion\n\nOpinion Editorial Cartoon Columns Comment Interview Lead Letters Open Page Corrections & Clarifications\n\nReal Estate\n\nScience\n\nScience\n\nISRO Question Corner\n\nScience For All The weekly newsletter from science writers takes the jargon out of science and puts the fun in!\n\nSEE ALL NEWSLETTERS\n\nSociety\n\nSociety Faith History & Culture\n\nSport\n\nSport Cricket Football Hockey Tennis Athletics Motorsport Races Other Sports\n\nBetween Wickets\n\nSpecials\n\nStates\n\nStates Andhra Pradesh Karnataka Kerala Tamil Nadu Telangana Andaman and Nicobar Islands Arunachal Pradesh Assam Bihar Chandigarh Chhattisgarh Daman, Diu, Dadra and Nagar Haveli Goa Gujarat Haryana Himachal Pradesh Jammu and Kashmir Jharkhand Lakshadweep Ladakh Madhya Pradesh Maharashtra Manipur Meghalaya Mizoram Nagaland Odisha Other States Punjab Rajasthan Sikkim Tripura Uttar Pradesh Uttarakhand West Bengal\n\nDecode Karnataka Focus Tamil Nadu\n\nKarnataka Today Your daily dose of news highlights from Karnataka\n\nSEE ALL NEWSLETTERS\n\nTechnology\n\nTechnology Gadgets Internet\n\nToday's Cache Your download of the top 5 technology stories of the day.\n\nSEE ALL NEWSLETTERS\n\nVisual Story Brandhub\n\nFebruary 28, 2025e-Paper\n\nSearch for topics, people, articles...\n\nIndia World Movies Sport Data Health Opinion Science Business Premium\n\nVideos Podcast Photos Crossword Newsletter\n\nLit for Life The Huddle\n\nRupee falls 28 paise to close at 87.46 against U.S. dollar\n\nRupee depreciates against U.S. dollar due to strength of American currency, negative equities trend, and tariff uncertainty\n\nPublished - February 28, 2025 04:21 pm IST - Mumbai\n\nPTI\n\nCopy link\n\nEmail\n\nFacebook\n\nTwitter\n\nTelegram\n\nLinkedIn\n\nWhatsApp\n\nReddit\n\nRemove SEE ALL\n\nFIIs offloaded equities worth ₹556.56 crore in the capital markets on net basis on Thursday (February 27, 2025), according to exchange data. File | Photo Credit: Reuters\n\nThe depreciated 28 paise to close at 87.46 (provisional) against the U.S. dollar on Friday (February 28, 2025), as the strength of the American currency and a negative trend in domestic equities dented investor sentiments.\n\nForex traders said the ongoing uncertainty surrounding tariff imposition by the U.S. has left financial markets in flux. Moreover, the tariff chaos has injected volatility and uncertainty into the U.S. Dollar Index.\n\nAt the interbank foreign exchange, the rupee opened at 87.32 against the greenback. During the session it fell to an intra-day low of 87.53 before ending the session at 87.46 (provisional) against the dollar, logging a loss of 28 paise from its previous close. ...

# %%
data[4].metadata
# Out:
# {'source': ' https://www.thehindu.com/business/markets/rupee-falls-28-paise-to-close-at-8746-against-us-dollar/article69274471.ece'}

# %% [markdown]
# #### STEP 3: Splitting the data text into chunks

# %% [markdown]
# Using the library from langchain -> RecursiveCharacterTextSplitter

# %%
text_splitter= RecursiveCharacterTextSplitter(
    chunk_size=1000,
    chunk_overlap=200
)

chunked_data=text_splitter.split_documents(data)

# %%
print("Number of chunks created by splitting: ", len(chunked_data))
# Out:
# Number of chunks created by splitting:  82

# %% [markdown]
# Let's print the number of characters in each chunk

# %%
for i in chunked_data:
    print(f"{len(i.page_content)}")
# Out:
# 956
# 621
# 923
# 812
# 783
# 517
# 839
# 794
# 919
# 935
# 911
# 976
# 998
# 987
# 957
# 995
# 938
# 332
# 973
# 705
# 714
# 919
# 899
# 977
# 527
# 917
# 726
# 955
# 966
# 995
# 939
# 733
# 994
# 999
# 995
# 832
# 928
# 580
# 482
# 987
# 814
# 980
# 337
# 996
# 352
# 983
# 821
# 875
# 817
# 936
# 995
# 982
# 955
# 733
# 994
# 999
# 995
# 832
# 928
# 580
# 482
# 987
# 702
# 994
# 464
# 996
# 352
# 983
# 821
# 990
# 916
# 942
# 826
# 896
# 804
# 802
# 839
# 975
# 995
# 969
# 768
# 481

# %% [markdown]
# #### STEP 4: Create vector embedings of these texts and store it into FAISS

# %%
# !pip install faiss-cpu
# Out:
# Collecting faiss-cpu
#   Downloading faiss_cpu-1.10.0-cp312-cp312-win_amd64.whl.metadata (4.5 kB)
# Requirement already satisfied: numpy<3.0,>=1.25.0 in c:\users\varsha kannan\appdata\local\programs\python\python312\lib\site-packages (from faiss-cpu) (1.26.4)
# Requirement already satisfied: packaging in c:\users\varsha kannan\appdata\local\programs\python\python312\lib\site-packages (from faiss-cpu) (24.2)
# Downloading faiss_cpu-1.10.0-cp312-cp312-win_amd64.whl (13.7 MB)
#    ---------------------------------------- 0.0/13.7 MB ? eta -:--:--
#    ------ --------------------------------- 2.1/13.7 MB 11.8 MB/s eta 0:00:01
#    ------------- -------------------------- 4.5/13.7 MB 11.7 MB/s eta 0:00:01
#    ---------------- ----------------------- 5.8/13.7 MB 9.5 MB/s eta 0:00:01
#    ------------------ --------------------- 6.3/13.7 MB 7.6 MB/s eta 0:00:01
#    ------------------- -------------------- 6.6/13.7 MB 6.6 MB/s eta 0:00:02
#    --------------------- ------------------ 7.3/13.7 MB 5.8 MB/s eta 0:00:02
#    ----------------------- ---------------- 8.1/13.7 MB 5.6 MB/s eta 0:00:01
#    --------------------------- ------------ 9.4/13.7 MB 5.5 MB/s eta 0:00:01
#    ------------------------------- -------- 10.7/13.7 MB 5.6 MB/s eta 0:00:01
#    ----------------------------------- ---- 12.1/13.7 MB 5.6 MB/s eta 0:00:01
#    ---------------------------------------  13.4/13.7 MB 5.7 MB/s eta 0:00:01
#    ---------------------------------------- 13.7/13.7 MB 5.7 MB/s eta 0:00:00
# Installing collected packages: faiss-cpu
# Successfully installed faiss-cpu-1.10.0
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
Vector_embeddings=OpenAIEmbeddings()

Faiss_vector_index=FAISS.from_documents(chunked_data,Vector_embeddings)
# Out:
# C:\Users\Varsha Kannan\AppData\Local\Temp\ipykernel_23768\1405398547.py:1: LangChainDeprecationWarning: The class `OpenAIEmbeddings` was deprecated in LangChain 0.0.9 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-openai package and should be used instead. To use it run `pip install -U :class:`~langchain-openai` and import as `from :class:`~langchain_openai import OpenAIEmbeddings``.
#   Vector_embeddings=OpenAIEmbeddings()

# %%
#save the index
Faiss_vector_index.save_local("vector_index.faiss")

# %%
vector_index_faiss = FAISS.load_local("vector_index.faiss", Vector_embeddings,allow_dangerous_deserialization=True)

# %% [markdown]
# Specifying the custom LLM

# %%
llm= OpenAI(
    temperature=0.7,
    max_tokens=500
)
# Out:
# C:\Users\Varsha Kannan\AppData\Local\Temp\ipykernel_23768\2081772960.py:1: LangChainDeprecationWarning: The class `OpenAI` was deprecated in LangChain 0.0.10 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-openai package and should be used instead. To use it run `pip install -U :class:`~langchain-openai` and import as `from :class:`~langchain_openai import OpenAI``.
#   llm= OpenAI(

# %% [markdown]
# #### STEP 5: Retrieve similar embeddings for a given question and call LLM to retrieve it

# %% [markdown]
# Using Retreival QA chain a library from langchain

# %%
q_a_chain=RetrievalQAWithSourcesChain.from_llm(llm=llm, retriever=vector_index_faiss.as_retriever())
q_a_chain
# Out:
# RetrievalQAWithSourcesChain(verbose=False, combine_documents_chain=MapReduceDocumentsChain(verbose=False, llm_chain=LLMChain(verbose=False, prompt=PromptTemplate(input_variables=['context', 'question'], input_types={}, partial_variables={}, template='Use the following portion of a long document to see if any of the text is relevant to answer the question. \nReturn any relevant text verbatim.\n{context}\nQuestion: {question}\nRelevant text, if any:'), llm=OpenAI(client=<openai.resources.completions.Completions object at 0x000001F84387C3E0>, async_client=<openai.resources.completions.AsyncCompletions object at 0x000001F84B64A930>, max_tokens=500, model_kwargs={}, openai_api_key='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', openai_proxy='', logit_bias={}), output_parser=StrOutputParser(), llm_kwargs={}), reduce_documents_chain=ReduceDocumentsChain(verbose=False, combine_documents_chain=StuffDocumentsChain(verbose=False, llm_chain=LLMChain(verbose=False, prompt=PromptTemplate(input_variables=['question', 'summaries'], input_types={}, partial_variables={}, template='Given the following extracted parts of a long document and a question, create a final answer with references ("SOURCES"). \nIf you don\'t know the answer, just say that you don\'t know. Don\'t try to make up an answer.\nALWAYS return a "SOURCES" part in your answer.\n\nQUESTION: Which state/country\'s law governs the interpretation of the contract?\n=========\nContent: This Agreement is governed by English law and the parties submit to the exclusive jurisdiction of the English courts in  relation to any dispute (contractual or non-contractual) concerning this Agreement save that either party may apply to any court for an  injunction or other relief to protect its Intellectual Property Rights.\nSource: 28-pl\nContent: No Waiver. Failure or delay in exercising any right or remedy under this Agreement shall not constitute a waiver of such (or any other)  right or remedy.\n\n11.7 Severability. The invalidity, illegality or unenforceability of any term (or part of a term) of this Agreement shall not affect the continuation  in force of the remainder of the term (if any) and this Agreement.\n\n11.8 No Agency. Except as expressly stated otherwise, nothing in this Agreement shall create an agency, partnership or joint venture of any  kind between the parties.\n\n11.9 No Third-Party Beneficiaries.\nSource: 30-pl\nContent: (b) if Google believes, in good faith, that the Distributor has violated or caused Google to violate any Anti-Bribery Laws (as  defined in Clause 8.5) or that such a violation is reasonably likely to occur,\nSource: 4-pl\n=========\nFINAL ANSWER: This Agreement is governed by English law.\nSOURCES: 28-pl\n\nQUESTION: What did the president say about Michael Jackson?\n=========\nContent: Madam Speaker, Madam Vice President, our First Lady and Second Gentleman. Members of Congress and the Cabinet. Justices of the Supreme Court. My fellow Americans.  \n\nLast year COVID-19 kept us apart. This year we are finally together again. \n\nTonight, we meet as Democrats Republicans and Independents. But most importantly as Americans. \n\nWith a duty to one another to the American people to the Constitution. \n\nAnd with an unwavering resolve that freedom will always triumph over tyranny. \n\nSix days ago, Russia’s Vladimir Putin sought to shake the foundations of the free world thinking he could make it bend to his menacing ways. But he badly miscalculated. \n\nHe thought he could roll into Ukraine and the world would roll over. Instead he met a wall of strength he never imagined. \n\nHe met the Ukrainian people. \n\nFrom President Zelenskyy to every Ukrainian, their fearlessness, their courage, their determination, inspires the world. \n\nGroups of citizens blocking tanks with their bodies. Everyone from students to retirees teachers turned soldiers de ...

# %% [markdown]
# #### STEP 6: Testing the RAG

# %%
query = "Can you tell me the reason for stock market crash?"
langchain.debug=True

q_a_chain({"question":query}, return_only_outputs=True)
# Out:
# [chain/start] [chain:RetrievalQAWithSourcesChain] Entering Chain run with input:
# {
#   "question": "Can you tell me the reason for stock market crash?"
# }
# [chain/start] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain] Entering Chain run with input:
# [inputs]
# [chain/start] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain > chain:LLMChain] Entering Chain run with input:
# {
#   "input_list": [
#     {
#       "context": "Written by Hitesh Vyas Mumbai | Updated: February 28, 2025 16:13 IST\n\n5 min read\n\nDecline in Indian equities mirrored losses across the wider Asian markets. (Express Photo: Sankhadeep Banerjee)\n\nIndian Stock Market Today: The Indian stock market has witnessed another bloodbath on Friday, with key indices crashing by 1.9 per cent and wiping out a staggering 18 per cent of investor wealth since September last year. The relentless sell-off has left investors reeling, with the Sensex plummeting 16 per cent (12,256 points) and the Nifty tumbling 18 per cent (3,991 points) since their record highs on September 26, 2024.",
#       "question": "Can you tell me the reason for stock market crash?"
#     },
#     {
#       "context": "Foreign portfolio investors (FPIs) have been at the forefront of the selling spree, pulling out a whopping Rs 2.13 lakh crore worth of stocks from the domestic market since October last year. This massive outflow has put additional pressure on the already battered markets. As investor confidence continues to erode, the big question on everyone’s mind is: when will the bleeding stop? Will the market find a bottom soon, or will the sell-off continue to wreak havoc on investor wealth? Will retail investors sell and keep away?\n\nOn Friday, domestic stock markets continued their downward spiral, tracking weak Asian stocks amid continued concerns over tariff threats from US President Donald Trump and also ahead of the release of India’s domestic gross domestic data (GDP) for FY2024-25 and October-December 2024 quarter. The general slowdown in the economy has also impacted the sentiment.\n\nStory continues below this ad",
#       "question": "Can you tell me the reason for stock market crash?"
#     },
#     {
#       "context": "Story continues below this ad\n\nAsian markets were the most affected by tariff news on Friday which led to a sharp correction in all the major Asian indices. The Japanese Nikkei index fell 3 per cent, followed by the Korean Kospi at 2.7 per cent and Hong Kong’s Hang Seng at 1.5 per cent. Crude oil prices witnessed gains overnight as tariff concerns led to a sharp rally from lower levels. Gold has been gaining ground in the last five months.\n\nThe BSE’s Sensex crashed 1395 points, or 1.87 per cent, to trade at 73,216.71 in the afternoon trade on Friday. The broader Nifty 50 tanked 1.9 per cent or 428 points, to 22,116.25 at 1 pm IST on Friday. Mid and small cap stocks continued to remain under heavy selling pressure. The BSE Smallcap index plunged by 3.30 per cent and BSE Midcap index fell 2.90 per cent.",
#       "question": "Can you tell me the reason for stock market crash?"
#     },
#     {
#       "context": "“Stock markets dislike uncertainty, and uncertainty has been on the rise ever since Trump was elected the US president. The spate of tariff announcements by Trump has been impacting markets and the latest announcement of additional 10 per cent tariff on China is a confirmation of the market view that Trump will use the initial months of his presidency to threaten countries with tariffs and then negotiate for a settlement favourable to the US,” said an analyst with a leading brokerage.\n\nIt needs to be seen how China will respond to the latest round of tariffs. Even now the markets have not discounted a full-blown trade war between the US and China. It is likely to be avoided. “However, the uncertainty element has increased as reflected in the sharp spike in CBOE volatility index to 21.13,” he said.\n\nStory continues below this ad",
#       "question": "Can you tell me the reason for stock market crash?"
#     }
#   ]
# }
# [llm/start] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain > chain:LLMChain > llm:OpenAI] Entering LLM run with input:
# {
#   "prompts": [
#     "Use the following portion of a long document to see if any of the text is relevant to answer the question. \nReturn any relevant text verbatim.\nWritten by Hitesh Vyas Mumbai | Updated: February 28, 2025 16:13 IST\n\n5 min read\n\nDecline in Indian equities mirrored losses across the wider Asian markets. (Express Photo: Sankhadeep Banerjee)\n\nIndian Stock Market Today: The Indian stock market has witnessed another bloodbath on Friday, with key indices crashing by 1.9 per cent and wiping out a staggering 18 per cent of investor wealth since September last year. The relentless sell-off has left investors reeling, with the Sensex plummeting 16 per cent (12,256 points) and the Nifty tumbling 18 per cent (3,991 points) since their record highs on September 26, 2024.\nQuestion: Can you tell me the reason for stock market crash?\nRelevant text, if any:"
#   ]
# }
# [llm/start] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain > chain:LLMChain > llm:OpenAI] Entering LLM run with input:
# {
#   "prompts": [
#     "Use the following portion of a long document to see if any of the text is relevant to answer the question. \nReturn any relevant text verbatim.\nForeign portfolio investors (FPIs) have been at the forefront of the selling spree, pulling out a whopping Rs 2.13 lakh crore worth of stocks from the domestic market since October last year. This massive outflow has put additional pressure on the already battered markets. As investor confidence continues to erode, the big question on everyone’s mind is: when will the bleeding stop? Will the market find a bottom soon, or will the sell-off continue to wreak havoc on investor wealth? Will retail investors sell and keep away?\n\nOn Friday, domestic stock markets continued their downward spiral, tracking weak Asian stocks amid continued concerns over tariff threats from US President Donald Trump and also ahead of the release of India’s domestic gross domestic data (GDP) for FY2024-25 and October-December 2024 quarter. The general slowdown in the economy has also impacted the sentiment.\n\nStory continues below this ad\nQuestion: Can you tell me the reason for stock market crash?\nRelevant text, if any:"
#   ]
# }
# [llm/start] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain > chain:LLMChain > llm:OpenAI] Entering LLM run with input:
# {
#   "prompts": [
#     "Use the following portion of a long document to see if any of the text is relevant to answer the question. \nReturn any relevant text verbatim.\nStory continues below this ad\n\nAsian markets were the most affected by tariff news on Friday which led to a sharp correction in all the major Asian indices. The Japanese Nikkei index fell 3 per cent, followed by the Korean Kospi at 2.7 per cent and Hong Kong’s Hang Seng at 1.5 per cent. Crude oil prices witnessed gains overnight as tariff concerns led to a sharp rally from lower levels. Gold has been gaining ground in the last five months.\n\nThe BSE’s Sensex crashed 1395 points, or 1.87 per cent, to trade at 73,216.71 in the afternoon trade on Friday. The broader Nifty 50 tanked 1.9 per cent or 428 points, to 22,116.25 at 1 pm IST on Friday. Mid and small cap stocks continued to remain under heavy selling pressure. The BSE Smallcap index plunged by 3.30 per cent and BSE Midcap index fell 2.90 per cent.\nQuestion: Can you tell me the reason for stock market crash?\nRelevant text, if any:"
#   ]
# }
# [llm/start] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain > chain:LLMChain > llm:OpenAI] Entering LLM run with input:
# {
#   "prompts": [
#     "Use the following portion of a long document to see if any of the text is relevant to answer the question. \nReturn any relevant text verbatim.\n“Stock markets dislike uncertainty, and uncertainty has been on the rise ever since Trump was elected the US president. The spate of tariff announcements by Trump has been impacting markets and the latest announcement of additional 10 per cent tariff on China is a confirmation of the market view that Trump will use the initial months of his presidency to threaten countries with tariffs and then negotiate for a settlement favourable to the US,” said an analyst with a leading brokerage.\n\nIt needs to be seen how China will respond to the latest round of tariffs. Even now the markets have not discounted a full-blown trade war between the US and China. It is likely to be avoided. “However, the uncertainty element has increased as reflected in the sharp spike in CBOE volatility index to 21.13,” he said.\n\nStory continues below this ad\nQuestion: Can you tell me the reason for stock market crash?\nRelevant text, if any:"
#   ]
# }
# [llm/end] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain > chain:LLMChain > llm:OpenAI] [1.72s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": " The Indian stock market has witnessed another bloodbath on Friday, with key indices crashing by 1.9 per cent and wiping out a staggering 18 per cent of investor wealth since September last year. The relentless sell-off has left investors reeling, with the Sensex plummeting 16 per cent (12,256 points) and the Nifty tumbling 18 per cent (3,991 points) since their record highs on September 26, 2024.",
#         "generation_info": {
#           "finish_reason": "stop",
#           "logprobs": null
#         },
#         "type": "Generation"
#       }
#     ]
#   ],
#   "llm_output": {
#     "token_usage": {
#       "prompt_tokens": 915,
#       "total_tokens": 1266,
#       "completion_tokens": 351
#     },
#     "model_name": "gpt-3.5-turbo-instruct"
#   },
#   "run": null,
#   "type": "LLMResult"
# }
# [llm/end] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain > chain:LLMChain > llm:OpenAI] [1.72s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": " Foreign portfolio investors (FPIs) have been at the forefront of the selling spree, pulling out a whopping Rs 2.13 lakh crore worth of stocks from the domestic market since October last year. This massive outflow has put additional pressure on the already battered markets. As investor confidence continues to erode...",
#         "generation_info": {
#           "finish_reason": "stop",
#           "logprobs": null
#         },
#         "type": "Generation"
#       }
#     ]
#   ],
#   "llm_output": {
#     "token_usage": {},
#     "model_name": "gpt-3.5-turbo-instruct"
#   },
#   "run": null,
#   "type": "LLMResult"
# }
# [llm/end] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain > chain:LLMChain > llm:OpenAI] [1.72s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": "\nThe BSE’s Sensex crashed 1395 points, or 1.87 per cent, to trade at 73,216.71 in the afternoon trade on Friday. The broader Nifty 50 tanked 1.9 per cent or 428 points, to 22,116.25 at 1 pm IST on Friday. Mid and small cap stocks continued to remain under heavy selling pressure. The BSE Smallcap index plunged by 3.30 per cent and BSE Midcap index fell 2.90 per cent.",
#         "generation_info": {
#           "finish_reason": "stop",
#           "logprobs": null
#         },
#         "type": "Generation"
#       }
#     ]
#   ],
#   "llm_output": {
#     "token_usage": {},
#     "model_name": "gpt-3.5-turbo-instruct"
#   },
#   "run": null,
#   "type": "LLMResult"
# }
# [llm/end] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain > chain:LLMChain > llm:OpenAI] [1.72s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": " \"Stock markets dislike uncertainty, and uncertainty has been on the rise ever since Trump was elected the US president. The spate of tariff announcements by Trump has been impacting markets and the latest announcement of additional 10 per cent tariff on China is a confirmation of the market view that Trump will use the initial months of his presidency to threaten countries with tariffs and then negotiate for a settlement favourable to the US.\"",
#         "generation_info": {
#           "finish_reason": "stop",
#           "logprobs": null
#         },
#         "type": "Generation"
#       }
#     ]
#   ],
#   "llm_output": {
#     "token_usage": {},
#     "model_name": "gpt-3.5-turbo-instruct"
#   },
#   "run": null,
#   "type": "LLMResult"
# }
# [chain/end] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain > chain:LLMChain] [1.72s] Exiting Chain run with output:
# {
#   "outputs": [
#     {
#       "text": " The Indian stock market has witnessed another bloodbath on Friday, with key indices crashing by 1.9 per cent and wiping out a staggering 18 per cent of investor wealth since September last year. The relentless sell-off has left investors reeling, with the Sensex plummeting 16 per cent (12,256 points) and the Nifty tumbling 18 per cent (3,991 points) since their record highs on September 26, 2024."
#     },
#     {
#       "text": " Foreign portfolio investors (FPIs) have been at the forefront of the selling spree, pulling out a whopping Rs 2.13 lakh crore worth of stocks from the domestic market since October last year. This massive outflow has put additional pressure on the already battered markets. As investor confidence continues to erode..."
#     },
#     {
#       "text": "\nThe BSE’s Sensex crashed 1395 points, or 1.87 per cent, to trade at 73,216.71 in the afternoon trade on Friday. The broader Nifty 50 tanked 1.9 per cent or 428 points, to 22,116.25 at 1 pm IST on Friday. Mid and small cap stocks continued to remain under heavy selling pressure. The BSE Smallcap index plunged by 3.30 per cent and BSE Midcap index fell 2.90 per cent."
#     },
#     {
#       "text": " \"Stock markets dislike uncertainty, and uncertainty has been on the rise ever since Trump was elected the US president. The spate of tariff announcements by Trump has been impacting markets and the latest announcement of additional 10 per cent tariff on China is a confirmation of the market view that Trump will use the initial months of his presidency to threaten countries with tariffs and then negotiate for a settlement favourable to the US.\""
#     }
#   ]
# }
# [chain/start] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain > chain:LLMChain] Entering Chain run with input:
# {
#   "question": "Can you tell me the reason for stock market crash?",
#   "summaries": "Content:  The Indian stock market has witnessed another bloodbath on Friday, with key indices crashing by 1.9 per cent and wiping out a staggering 18 per cent of investor wealth since September last year. The relentless sell-off has left investors reeling, with the Sensex plummeting 16 per cent (12,256 points) and the Nifty tumbling 18 per cent (3,991 points) since their record highs on September 26, 2024.\nSource:  https://indianexpress.com/article/business/market/stock-market-crash-today-sensex-nifty-live-updates-9860683/\n\nContent:  Foreign portfolio investors (FPIs) have been at the forefront of the selling spree, pulling out a whopping Rs 2.13 lakh crore worth of stocks from the domestic market since October last year. This massive outflow has put additional pressure on the already battered markets. As investor confidence continues to erode...\nSource:  https://indianexpress.com/article/business/market/stock-market-crash-today-sensex-nifty-live-updates-9860683/\n\nContent: \nThe BSE’s Sensex crashed 1395 points, or 1.87 per cent, to trade at 73,216.71 in the afternoon trade on Friday. The broader Nifty 50 tanked 1.9 per cent or 428 points, to 22,116.25 at 1 pm IST on Friday. Mid and small cap stocks continued to remain under heavy selling pressure. The BSE Smallcap index plunged by 3.30 per cent and BSE Midcap index fell 2.90 per cent.\nSource:  https://indianexpress.com/article/business/market/stock-market-crash-today-sensex-nifty-live-updates-9860683/\n\nContent:  \"Stock markets dislike uncertainty, and uncertainty has been on the rise ever since Trump was elected the US president. The spate of tariff announcements by Trump has been impacting markets and the latest announcement of additional 10 per cent tariff on China is a confirmation of the market view that Trump will use the initial months of his presidency to threaten countries with tariffs and then negotiate for a settlement favourable to the US.\"\nSource:  https://indianexpress.com/article/business/market/stock-market-crash-today-sensex-nifty-live-updates-9860683/"
# }
# [llm/start] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain > chain:LLMChain > llm:OpenAI] Entering LLM run with input:
# {
#   "prompts": [
#     "Given the following extracted parts of a long document and a question, create a final answer with references (\"SOURCES\"). \nIf you don't know the answer, just say that you don't know. Don't try to make up an answer.\nALWAYS return a \"SOURCES\" part in your answer.\n\nQUESTION: Which state/country's law governs the interpretation of the contract?\n=========\nContent: This Agreement is governed by English law and the parties submit to the exclusive jurisdiction of the English courts in  relation to any dispute (contractual or non-contractual) concerning this Agreement save that either party may apply to any court for an  injunction or other relief to protect its Intellectual Property Rights.\nSource: 28-pl\nContent: No Waiver. Failure or delay in exercising any right or remedy under this Agreement shall not constitute a waiver of such (or any other)  right or remedy.\n\n11.7 Severability. The invalidity, illegality or unenforceability of any term (or part of a term) of this Agreement shall not affect the continuation  in force of the remainder of the term (if any) and this Agreement.\n\n11.8 No Agency. Except as expressly stated otherwise, nothing in this Agreement shall create an agency, partnership or joint venture of any  kind between the parties.\n\n11.9 No Third-Party Beneficiaries.\nSource: 30-pl\nContent: (b) if Google believes, in good faith, that the Distributor has violated or caused Google to violate any Anti-Bribery Laws (as  defined in Clause 8.5) or that such a violation is reasonably likely to occur,\nSource: 4-pl\n=========\nFINAL ANSWER: This Agreement is governed by English law.\nSOURCES: 28-pl\n\nQUESTION: What did the president say about Michael Jackson?\n=========\nContent: Madam Speaker, Madam Vice President, our First Lady and Second Gentleman. Members of Congress and the Cabinet. Justices of the Supreme Court. My fellow Americans.  \n\nLast year COVID-19 kept us apart. This year we are finally together again. \n\nTonight, we meet as Democrats Republicans and Independents. But most importantly as Americans. \n\nWith a duty to one another to the American people to the Constitution. \n\nAnd with an unwavering resolve that freedom will always triumph over tyranny. \n\nSix days ago, Russia’s Vladimir Putin sought to shake the foundations of the free world thinking he could make it bend to his menacing ways. But he badly miscalculated. \n\nHe thought he could roll into Ukraine and the world would roll over. Instead he met a wall of strength he never imagined. \n\nHe met the Ukrainian people. \n\nFrom President Zelenskyy to every Ukrainian, their fearlessness, their courage, their determination, inspires the world. \n\nGroups of citizens blocking tanks with their bodies. Everyone from students to retirees teachers turned soldiers defending their homeland.\nSource: 0-pl\nContent: And we won’t stop. \n\nWe have lost so much to COVID-19. Time with one another. And worst of all, so much loss of life. \n\nLet’s use this moment to reset. Let’s stop looking at COVID-19 as a partisan dividing line and see it for what it is: A God-awful disease.  \n\nLet’s stop seeing each other as enemies, and start seeing each other for who we really are: Fellow Americans.  \n\nWe can’t change how divided we’ve been. But we can change how we move forward—on COVID-19 and other issues we must face together. \n\nI recently visited the New York City Police Department days after the funerals of Officer Wilbert Mora and his partner, Officer Jason Rivera. \n\nThey were responding to a 9-1-1 call when a man shot and killed them with a stolen gun. \n\nOfficer Mora was 27 years old. \n\nOfficer Rivera was 22. \n\nBoth Dominican Americans who’d grown up on the same streets they later chose to patrol as police officers. \n\nI spoke with their families and told them that we are forever in debt for their sacrifice, and we will carry on their mission to restore the trust and safety every community deserves.\nSource: 24-pl\nContent: And a prou ...
#   ]
# }
# [llm/end] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain > chain:LLMChain > llm:OpenAI] [1.43s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": " The stock market has crashed due to the uncertainty and impact of tariffs by the US president, as well as large foreign portfolio investors pulling out from the market.\nSOURCES: https://indianexpress.com/article/business/market/stock-market-crash-today-sensex-nifty-live-updates-9860683/",
#         "generation_info": {
#           "finish_reason": "stop",
#           "logprobs": null
#         },
#         "type": "Generation"
#       }
#     ]
#   ],
#   "llm_output": {
#     "token_usage": {
#       "prompt_tokens": 1842,
#       "total_tokens": 1905,
#       "completion_tokens": 63
#     },
#     "model_name": "gpt-3.5-turbo-instruct"
#   },
#   "run": null,
#   "type": "LLMResult"
# }
# [chain/end] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain > chain:LLMChain] [1.43s] Exiting Chain run with output:
# {
#   "text": " The stock market has crashed due to the uncertainty and impact of tariffs by the US president, as well as large foreign portfolio investors pulling out from the market.\nSOURCES: https://indianexpress.com/article/business/market/stock-market-crash-today-sensex-nifty-live-updates-9860683/"
# }
# [chain/end] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain] [3.16s] Exiting Chain run with output:
# {
#   "output_text": " The stock market has crashed due to the uncertainty and impact of tariffs by the US president, as well as large foreign portfolio investors pulling out from the market.\nSOURCES: https://indianexpress.com/article/business/market/stock-market-crash-today-sensex-nifty-live-updates-9860683/"
# }
# [chain/end] [chain:RetrievalQAWithSourcesChain] [3.58s] Exiting Chain run with output:
# {
#   "answer": " The stock market has crashed due to the uncertainty and impact of tariffs by the US president, as well as large foreign portfolio investors pulling out from the market.\n",
#   "sources": "https://indianexpress.com/article/business/market/stock-market-crash-today-sensex-nifty-live-updates-9860683/"
# }
# {'answer': ' The stock market has crashed due to the uncertainty and impact of tariffs by the US president, as well as large foreign portfolio investors pulling out from the market.\n',
#  'sources': 'https://indianexpress.com/article/business/market/stock-market-crash-today-sensex-nifty-live-updates-9860683/'}

# %%
query = "What are the stocks that gained over 10% in BSE?"
#langchain.debug=True

q_a_chain({"question":query}, return_only_outputs=True)
# Out:
# [chain/start] [chain:RetrievalQAWithSourcesChain] Entering Chain run with input:
# {
#   "question": "What are the stocks that gained over 10% in BSE?"
# }
# [chain/start] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain] Entering Chain run with input:
# [inputs]
# [chain/start] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain > chain:LLMChain] Entering Chain run with input:
# {
#   "input_list": [
#     {
#       "context": "Follow us\n\nShare\n\nFont Size\n\nAbcSmall\n\nAbcMedium\n\nAbcLarge\n\nSave\n\nPrint\n\nComment\n\nSynopsis\n\nIn the Nifty 50 index, 5 stocks ended in the green, while 44 stocks closed in the red in today's trade.\n\nNEW DELHI: A number of stocks rose in excess of 10% on BSE as domestic equity indices, BSE Sensex and NSE Nifty, ended in the red on Friday. These high-performing stocks that rallied more than 10% during the session included, Medico Remedies(11.81%), Home First Finance Co(11.56%) and Transpact Enterprise(10.00%).\n\nThe 30-share Sensex ended 1414.33 points down at 73198.1, while the 50-share Nifty index closed 420.35 points down at 22124.7. In the Nifty 50 index, 5 stocks ended in the green, while 44 stocks closed in the red.",
#       "question": "What are the stocks that gained over 10% in BSE?"
#     },
#     {
#       "context": "Benchmarks\n\nNifty22,124.70-420.35\n\nFEATURED FUNDS\n\n★★★★★\n\nHSBC Large Cap Fund Direct-Growth\n\n5Y Return\n\n15.12 %\n\nInvest Now\n\nFEATURED FUNDS\n\n★★★★★\n\nCanara Robeco ELSS Tax Saver Regular - Growth\n\n5Y Return\n\n16.38 %\n\nInvest Now\n\nEnglish EditionEnglish Editionहिन्दीગુજરાતીमराठीবাংলাಕನ್ನಡമലയാളംதமிழ்తెలుగు\n\n| Today's ePaper\n\nMy Watchlist Subscribe\n\nSign In\n\nBusiness News›Markets›Stocks›Stock Watch›Sensex falls! But these stocks gained over 10% on BSE\n\nThe Economic Times daily newspaper is available online now.\n\nRead Today's Paper\n\nSensex falls! But these stocks gained over 10% on BSE\n\nSECTIONS\n\nSensex falls! But these stocks gained over 10% on BSE\n\nETMarkets.comLast Updated: Feb 28, 2025, 05:22:00 PM IST\n\nRate Story\n\nFollow us\n\nShare\n\nFont Size\n\nAbcSmall\n\nAbcMedium\n\nAbcLarge\n\nSave\n\nPrint\n\nComment\n\nSynopsis\n\nIn the Nifty 50 index, 5 stocks ended in the green, while 44 stocks closed in the red in today's trade.",
#       "question": "What are the stocks that gained over 10% in BSE?"
#     },
#     {
#       "context": "Top Trending Stocks: SBI Share Price, Axis Bank Share Price, HDFC Bank Share Price, Infosys Share Price, Wipro Share Price, NTPC Share Price\n\n...moreless\n\n(You can now subscribe to our ETMarkets WhatsApp channel)\n\nRead More News on\n\nStocks SurgedStocks Surged updatesStocks Surged over 10Stocks Surged over 10 on BSESmallcap stocks surged over 10Midcap stocks surged over 10Stocks surged on BSE\n\n(What's moving Sensex and Nifty Track latest market news, stock tips, Budget 2025, Share Market on Budget 2025 and expert advice, on ETMarkets. Also, ETMarkets.com is now on Telegram. For fastest news alerts on financial markets, investment strategies and stocks alerts, subscribe to our Telegram feeds .)\n\nSubscribe to ET Prime and read the Economic Times ePaper Online.and Sensex Today.\n\nTop Trending Stocks: SBI Share Price, Axis Bank Share Price, HDFC Bank Share Price, Infosys Share Price, Wipro Share Price, NTPC Share Price\n\n...moreless",
#       "question": "What are the stocks that gained over 10% in BSE?"
#     },
#     {
#       "context": "Top Trending Stocks: SBI Share Price, Axis Bank Share Price, HDFC Bank Share Price, Infosys Share Price, Wipro Share Price, NTPC Share Price\n\n...moreless\n\nPrime ExclusivesInvestment IdeasStock Report PlusePaperWealth Edition\n\nLucky Baskhars run amok as gold loan defaults dazzle across banks’ portfolios\n\nElon Musk effect: How a social media tussle is messing up space exploration\n\nAfter two decades of wait, KG-98/2 finally ignites ONGC’s revival path\n\nHow Porter built a universal appeal with small business owners\n\nWill passenger vehicle sales stall again despite tax cuts?\n\nStock Radar: Bajaj Finance rallies 27% in 3 months to hit fresh record highs; time to buy or book profits?\n\n1\n\n2\n\n3\n\nView all Stories\n\nMost Searched Stocks",
#       "question": "What are the stocks that gained over 10% in BSE?"
#     }
#   ]
# }
# [llm/start] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain > chain:LLMChain > llm:OpenAI] Entering LLM run with input:
# {
#   "prompts": [
#     "Use the following portion of a long document to see if any of the text is relevant to answer the question. \nReturn any relevant text verbatim.\nFollow us\n\nShare\n\nFont Size\n\nAbcSmall\n\nAbcMedium\n\nAbcLarge\n\nSave\n\nPrint\n\nComment\n\nSynopsis\n\nIn the Nifty 50 index, 5 stocks ended in the green, while 44 stocks closed in the red in today's trade.\n\nNEW DELHI: A number of stocks rose in excess of 10% on BSE as domestic equity indices, BSE Sensex and NSE Nifty, ended in the red on Friday. These high-performing stocks that rallied more than 10% during the session included, Medico Remedies(11.81%), Home First Finance Co(11.56%) and Transpact Enterprise(10.00%).\n\nThe 30-share Sensex ended 1414.33 points down at 73198.1, while the 50-share Nifty index closed 420.35 points down at 22124.7. In the Nifty 50 index, 5 stocks ended in the green, while 44 stocks closed in the red.\nQuestion: What are the stocks that gained over 10% in BSE?\nRelevant text, if any:"
#   ]
# }
# [llm/start] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain > chain:LLMChain > llm:OpenAI] Entering LLM run with input:
# {
#   "prompts": [
#     "Use the following portion of a long document to see if any of the text is relevant to answer the question. \nReturn any relevant text verbatim.\nBenchmarks\n\nNifty22,124.70-420.35\n\nFEATURED FUNDS\n\n★★★★★\n\nHSBC Large Cap Fund Direct-Growth\n\n5Y Return\n\n15.12 %\n\nInvest Now\n\nFEATURED FUNDS\n\n★★★★★\n\nCanara Robeco ELSS Tax Saver Regular - Growth\n\n5Y Return\n\n16.38 %\n\nInvest Now\n\nEnglish EditionEnglish Editionहिन्दीગુજરાતીमराठीবাংলাಕನ್ನಡമലയാളംதமிழ்తెలుగు\n\n| Today's ePaper\n\nMy Watchlist Subscribe\n\nSign In\n\nBusiness News›Markets›Stocks›Stock Watch›Sensex falls! But these stocks gained over 10% on BSE\n\nThe Economic Times daily newspaper is available online now.\n\nRead Today's Paper\n\nSensex falls! But these stocks gained over 10% on BSE\n\nSECTIONS\n\nSensex falls! But these stocks gained over 10% on BSE\n\nETMarkets.comLast Updated: Feb 28, 2025, 05:22:00 PM IST\n\nRate Story\n\nFollow us\n\nShare\n\nFont Size\n\nAbcSmall\n\nAbcMedium\n\nAbcLarge\n\nSave\n\nPrint\n\nComment\n\nSynopsis\n\nIn the Nifty 50 index, 5 stocks ended in the green, while 44 stocks closed in the red in today's trade.\nQuestion: What are the stocks that gained over 10% in BSE?\nRelevant text, if any:"
#   ]
# }
# [llm/start] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain > chain:LLMChain > llm:OpenAI] Entering LLM run with input:
# {
#   "prompts": [
#     "Use the following portion of a long document to see if any of the text is relevant to answer the question. \nReturn any relevant text verbatim.\nTop Trending Stocks: SBI Share Price, Axis Bank Share Price, HDFC Bank Share Price, Infosys Share Price, Wipro Share Price, NTPC Share Price\n\n...moreless\n\n(You can now subscribe to our ETMarkets WhatsApp channel)\n\nRead More News on\n\nStocks SurgedStocks Surged updatesStocks Surged over 10Stocks Surged over 10 on BSESmallcap stocks surged over 10Midcap stocks surged over 10Stocks surged on BSE\n\n(What's moving Sensex and Nifty Track latest market news, stock tips, Budget 2025, Share Market on Budget 2025 and expert advice, on ETMarkets. Also, ETMarkets.com is now on Telegram. For fastest news alerts on financial markets, investment strategies and stocks alerts, subscribe to our Telegram feeds .)\n\nSubscribe to ET Prime and read the Economic Times ePaper Online.and Sensex Today.\n\nTop Trending Stocks: SBI Share Price, Axis Bank Share Price, HDFC Bank Share Price, Infosys Share Price, Wipro Share Price, NTPC Share Price\n\n...moreless\nQuestion: What are the stocks that gained over 10% in BSE?\nRelevant text, if any:"
#   ]
# }
# [llm/start] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain > chain:LLMChain > llm:OpenAI] Entering LLM run with input:
# {
#   "prompts": [
#     "Use the following portion of a long document to see if any of the text is relevant to answer the question. \nReturn any relevant text verbatim.\nTop Trending Stocks: SBI Share Price, Axis Bank Share Price, HDFC Bank Share Price, Infosys Share Price, Wipro Share Price, NTPC Share Price\n\n...moreless\n\nPrime ExclusivesInvestment IdeasStock Report PlusePaperWealth Edition\n\nLucky Baskhars run amok as gold loan defaults dazzle across banks’ portfolios\n\nElon Musk effect: How a social media tussle is messing up space exploration\n\nAfter two decades of wait, KG-98/2 finally ignites ONGC’s revival path\n\nHow Porter built a universal appeal with small business owners\n\nWill passenger vehicle sales stall again despite tax cuts?\n\nStock Radar: Bajaj Finance rallies 27% in 3 months to hit fresh record highs; time to buy or book profits?\n\n1\n\n2\n\n3\n\nView all Stories\n\nMost Searched Stocks\nQuestion: What are the stocks that gained over 10% in BSE?\nRelevant text, if any:"
#   ]
# }
# [llm/end] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain > chain:LLMChain > llm:OpenAI] [1.51s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": " \"These high-performing stocks that rallied more than 10% during the session included, Medico Remedies(11.81%), Home First Finance Co(11.56%) and Transpact Enterprise(10.00%).\"",
#         "generation_info": {
#           "finish_reason": "stop",
#           "logprobs": null
#         },
#         "type": "Generation"
#       }
#     ]
#   ],
#   "llm_output": {
#     "token_usage": {
#       "prompt_tokens": 1169,
#       "total_tokens": 1348,
#       "completion_tokens": 179
#     },
#     "model_name": "gpt-3.5-turbo-instruct"
#   },
#   "run": null,
#   "type": "LLMResult"
# }
# [llm/end] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain > chain:LLMChain > llm:OpenAI] [1.51s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": "\n\nIn today's trade on BSE, there were several stocks that gained over 10%. Some of these stocks include HSBC Large Cap Fund Direct-Growth, Canara Robeco ELSS Tax Saver Regular - Growth, and several others. These stocks have shown strong performance and have outperformed the market, despite the overall decline in the Sensex. ",
#         "generation_info": {
#           "finish_reason": "stop",
#           "logprobs": null
#         },
#         "type": "Generation"
#       }
#     ]
#   ],
#   "llm_output": {
#     "token_usage": {},
#     "model_name": "gpt-3.5-turbo-instruct"
#   },
#   "run": null,
#   "type": "LLMResult"
# }
# [llm/end] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain > chain:LLMChain > llm:OpenAI] [1.51s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": " Smallcap stocks surged over 10, Midcap stocks surged over 10, Stocks surged on BSE",
#         "generation_info": {
#           "finish_reason": "stop",
#           "logprobs": null
#         },
#         "type": "Generation"
#       }
#     ]
#   ],
#   "llm_output": {
#     "token_usage": {},
#     "model_name": "gpt-3.5-turbo-instruct"
#   },
#   "run": null,
#   "type": "LLMResult"
# }
# [llm/end] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain > chain:LLMChain > llm:OpenAI] [1.51s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": "\nTop Trending Stocks: SBI Share Price, Axis Bank Share Price, HDFC Bank Share Price, Infosys Share Price, Wipro Share Price, NTPC Share Price",
#         "generation_info": {
#           "finish_reason": "stop",
#           "logprobs": null
#         },
#         "type": "Generation"
#       }
#     ]
#   ],
#   "llm_output": {
#     "token_usage": {},
#     "model_name": "gpt-3.5-turbo-instruct"
#   },
#   "run": null,
#   "type": "LLMResult"
# }
# [chain/end] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain > chain:LLMChain] [1.51s] Exiting Chain run with output:
# {
#   "outputs": [
#     {
#       "text": " \"These high-performing stocks that rallied more than 10% during the session included, Medico Remedies(11.81%), Home First Finance Co(11.56%) and Transpact Enterprise(10.00%).\""
#     },
#     {
#       "text": "\n\nIn today's trade on BSE, there were several stocks that gained over 10%. Some of these stocks include HSBC Large Cap Fund Direct-Growth, Canara Robeco ELSS Tax Saver Regular - Growth, and several others. These stocks have shown strong performance and have outperformed the market, despite the overall decline in the Sensex. "
#     },
#     {
#       "text": " Smallcap stocks surged over 10, Midcap stocks surged over 10, Stocks surged on BSE"
#     },
#     {
#       "text": "\nTop Trending Stocks: SBI Share Price, Axis Bank Share Price, HDFC Bank Share Price, Infosys Share Price, Wipro Share Price, NTPC Share Price"
#     }
#   ]
# }
# [chain/start] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain > chain:LLMChain] Entering Chain run with input:
# {
#   "question": "What are the stocks that gained over 10% in BSE?",
#   "summaries": "Content:  \"These high-performing stocks that rallied more than 10% during the session included, Medico Remedies(11.81%), Home First Finance Co(11.56%) and Transpact Enterprise(10.00%).\"\nSource:  https://economictimes.indiatimes.com/markets/stocks/stock-watch/sensex-falls-but-these-stocks-gained-over-10-on-bse/articleshow/118628952.cms\n\nContent: \n\nIn today's trade on BSE, there were several stocks that gained over 10%. Some of these stocks include HSBC Large Cap Fund Direct-Growth, Canara Robeco ELSS Tax Saver Regular - Growth, and several others. These stocks have shown strong performance and have outperformed the market, despite the overall decline in the Sensex. \nSource:  https://economictimes.indiatimes.com/markets/stocks/stock-watch/sensex-falls-but-these-stocks-gained-over-10-on-bse/articleshow/118628952.cms\n\nContent:  Smallcap stocks surged over 10, Midcap stocks surged over 10, Stocks surged on BSE\nSource:  https://economictimes.indiatimes.com/markets/stocks/stock-watch/sensex-falls-but-these-stocks-gained-over-10-on-bse/articleshow/118628952.cms\n\nContent: \nTop Trending Stocks: SBI Share Price, Axis Bank Share Price, HDFC Bank Share Price, Infosys Share Price, Wipro Share Price, NTPC Share Price\nSource:  https://economictimes.indiatimes.com/markets/stocks/stock-watch/sensex-falls-but-these-stocks-gained-over-10-on-bse/articleshow/118628952.cms"
# }
# [llm/start] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain > chain:LLMChain > llm:OpenAI] Entering LLM run with input:
# {
#   "prompts": [
#     "Given the following extracted parts of a long document and a question, create a final answer with references (\"SOURCES\"). \nIf you don't know the answer, just say that you don't know. Don't try to make up an answer.\nALWAYS return a \"SOURCES\" part in your answer.\n\nQUESTION: Which state/country's law governs the interpretation of the contract?\n=========\nContent: This Agreement is governed by English law and the parties submit to the exclusive jurisdiction of the English courts in  relation to any dispute (contractual or non-contractual) concerning this Agreement save that either party may apply to any court for an  injunction or other relief to protect its Intellectual Property Rights.\nSource: 28-pl\nContent: No Waiver. Failure or delay in exercising any right or remedy under this Agreement shall not constitute a waiver of such (or any other)  right or remedy.\n\n11.7 Severability. The invalidity, illegality or unenforceability of any term (or part of a term) of this Agreement shall not affect the continuation  in force of the remainder of the term (if any) and this Agreement.\n\n11.8 No Agency. Except as expressly stated otherwise, nothing in this Agreement shall create an agency, partnership or joint venture of any  kind between the parties.\n\n11.9 No Third-Party Beneficiaries.\nSource: 30-pl\nContent: (b) if Google believes, in good faith, that the Distributor has violated or caused Google to violate any Anti-Bribery Laws (as  defined in Clause 8.5) or that such a violation is reasonably likely to occur,\nSource: 4-pl\n=========\nFINAL ANSWER: This Agreement is governed by English law.\nSOURCES: 28-pl\n\nQUESTION: What did the president say about Michael Jackson?\n=========\nContent: Madam Speaker, Madam Vice President, our First Lady and Second Gentleman. Members of Congress and the Cabinet. Justices of the Supreme Court. My fellow Americans.  \n\nLast year COVID-19 kept us apart. This year we are finally together again. \n\nTonight, we meet as Democrats Republicans and Independents. But most importantly as Americans. \n\nWith a duty to one another to the American people to the Constitution. \n\nAnd with an unwavering resolve that freedom will always triumph over tyranny. \n\nSix days ago, Russia’s Vladimir Putin sought to shake the foundations of the free world thinking he could make it bend to his menacing ways. But he badly miscalculated. \n\nHe thought he could roll into Ukraine and the world would roll over. Instead he met a wall of strength he never imagined. \n\nHe met the Ukrainian people. \n\nFrom President Zelenskyy to every Ukrainian, their fearlessness, their courage, their determination, inspires the world. \n\nGroups of citizens blocking tanks with their bodies. Everyone from students to retirees teachers turned soldiers defending their homeland.\nSource: 0-pl\nContent: And we won’t stop. \n\nWe have lost so much to COVID-19. Time with one another. And worst of all, so much loss of life. \n\nLet’s use this moment to reset. Let’s stop looking at COVID-19 as a partisan dividing line and see it for what it is: A God-awful disease.  \n\nLet’s stop seeing each other as enemies, and start seeing each other for who we really are: Fellow Americans.  \n\nWe can’t change how divided we’ve been. But we can change how we move forward—on COVID-19 and other issues we must face together. \n\nI recently visited the New York City Police Department days after the funerals of Officer Wilbert Mora and his partner, Officer Jason Rivera. \n\nThey were responding to a 9-1-1 call when a man shot and killed them with a stolen gun. \n\nOfficer Mora was 27 years old. \n\nOfficer Rivera was 22. \n\nBoth Dominican Americans who’d grown up on the same streets they later chose to patrol as police officers. \n\nI spoke with their families and told them that we are forever in debt for their sacrifice, and we will carry on their mission to restore the trust and safety every community deserves.\nSource: 24-pl\nContent: And a prou ...
#   ]
# }
# [llm/end] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain > chain:LLMChain > llm:OpenAI] [1.73s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": " The high-performing stocks that gained over 10% during the session on BSE were Medico Remedies, Home First Finance Co, and Transpact Enterprise.\nSOURCES: https://economictimes.indiatimes.com/markets/stocks/stock-watch/sensex-falls-but-these-stocks-gained-over-10-on-bse/articleshow/118628952.cms",
#         "generation_info": {
#           "finish_reason": "stop",
#           "logprobs": null
#         },
#         "type": "Generation"
#       }
#     ]
#   ],
#   "llm_output": {
#     "token_usage": {
#       "prompt_tokens": 1726,
#       "total_tokens": 1804,
#       "completion_tokens": 78
#     },
#     "model_name": "gpt-3.5-turbo-instruct"
#   },
#   "run": null,
#   "type": "LLMResult"
# }
# [chain/end] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain > chain:LLMChain] [1.73s] Exiting Chain run with output:
# {
#   "text": " The high-performing stocks that gained over 10% during the session on BSE were Medico Remedies, Home First Finance Co, and Transpact Enterprise.\nSOURCES: https://economictimes.indiatimes.com/markets/stocks/stock-watch/sensex-falls-but-these-stocks-gained-over-10-on-bse/articleshow/118628952.cms"
# }
# [chain/end] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain] [3.25s] Exiting Chain run with output:
# {
#   "output_text": " The high-performing stocks that gained over 10% during the session on BSE were Medico Remedies, Home First Finance Co, and Transpact Enterprise.\nSOURCES: https://economictimes.indiatimes.com/markets/stocks/stock-watch/sensex-falls-but-these-stocks-gained-over-10-on-bse/articleshow/118628952.cms"
# }
# [chain/end] [chain:RetrievalQAWithSourcesChain] [3.99s] Exiting Chain run with output:
# {
#   "answer": " The high-performing stocks that gained over 10% during the session on BSE were Medico Remedies, Home First Finance Co, and Transpact Enterprise.\n",
#   "sources": "https://economictimes.indiatimes.com/markets/stocks/stock-watch/sensex-falls-but-these-stocks-gained-over-10-on-bse/articleshow/118628952.cms"
# }
# {'answer': ' The high-performing stocks that gained over 10% during the session on BSE were Medico Remedies, Home First Finance Co, and Transpact Enterprise.\n',
#  'sources': 'https://economictimes.indiatimes.com/markets/stocks/stock-watch/sensex-falls-but-these-stocks-gained-over-10-on-bse/articleshow/118628952.cms'}

# %%
query = "Why is the price of Rupee depreciating"
#langchain.debug=True

q_a_chain({"question":query}, return_only_outputs=True)
# Out:
# [chain/start] [chain:RetrievalQAWithSourcesChain] Entering Chain run with input:
# {
#   "question": "Why is the price of Rupee depreciating"
# }
# [chain/start] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain] Entering Chain run with input:
# [inputs]
# [chain/start] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain > chain:LLMChain] Entering Chain run with input:
# {
#   "input_list": [
#     {
#       "context": "Reddit\n\nRemove SEE ALL\n\nFIIs offloaded equities worth ₹556.56 crore in the capital markets on net basis on Thursday (February 27, 2025), according to exchange data. File | Photo Credit: Reuters\n\nThe depreciated 28 paise to close at 87.46 (provisional) against the U.S. dollar on Friday (February 28, 2025), as the strength of the American currency and a negative trend in domestic equities dented investor sentiments.\n\nForex traders said the ongoing uncertainty surrounding tariff imposition by the U.S. has left financial markets in flux. Moreover, the tariff chaos has injected volatility and uncertainty into the U.S. Dollar Index.\n\nAt the interbank foreign exchange, the rupee opened at 87.32 against the greenback. During the session it fell to an intra-day low of 87.53 before ending the session at 87.46 (provisional) against the dollar, logging a loss of 28 paise from its previous close.",
#       "question": "Why is the price of Rupee depreciating"
#     },
#     {
#       "context": "Today's Cache Your download of the top 5 technology stories of the day.\n\nSEE ALL NEWSLETTERS\n\nVisual Story Brandhub\n\nFebruary 28, 2025e-Paper\n\nSearch for topics, people, articles...\n\nIndia World Movies Sport Data Health Opinion Science Business Premium\n\nVideos Podcast Photos Crossword Newsletter\n\nLit for Life The Huddle\n\nRupee falls 28 paise to close at 87.46 against U.S. dollar\n\nRupee depreciates against U.S. dollar due to strength of American currency, negative equities trend, and tariff uncertainty\n\nPublished - February 28, 2025 04:21 pm IST - Mumbai\n\nPTI\n\nCopy link\n\nEmail\n\nFacebook\n\nTwitter\n\nTelegram\n\nLinkedIn\n\nWhatsApp\n\nReddit\n\nRemove SEE ALL\n\nFIIs offloaded equities worth ₹556.56 crore in the capital markets on net basis on Thursday (February 27, 2025), according to exchange data. File | Photo Credit: Reuters",
#       "question": "Why is the price of Rupee depreciating"
#     },
#     {
#       "context": "In the domestic equity market, the 30-share BSE Sensex declined 1,414.33 points, or 1.90%, to settle at 73,198.10, while the Nifty fell 420.35 points, or 1.86%, to 22,124.70 points.\n\nMeanwhile, the Reserve Bank of India (RBI) on Friday (February 28, 2025) conducted U.S. dollar-rupee swap worth $10 billion for injecting long term liquidity in the system, with the auction eliciting robust demand. The settlement of auction will take place on March 4 and March 6.\n\nUnder the swap exercise, a bank shall sell U.S. dollars to the RBI and simultaneously agree to buy the same amount of U.S. dollars at the end of the swap period.\n\nForeign Institutional Investors (FIIs) offloaded equities worth ₹556.56 crore in the capital markets on net basis on Thursday (February 27, 2025), according to exchange data.",
#       "question": "Why is the price of Rupee depreciating"
#     },
#     {
#       "context": "On Thursday (February 27, 2025), the rupee settled almost flat with a marginal gain of 1 paisa at 87.18 against U.S. dollar.\n\nElevated greenback against major crosses and sustained FII outflows also contributed to the decline in the domestic unit, forex traders said.\n\nBesides, month-end dollar demand by importers amid uncertainty over U.S. trade tariffs also boosted the American currency.\n\nMeanwhile, the dollar index, which gauges the greenback’s strength against a basket of six currencies, was trading 0.08% higher at 107.33.\n\nBrent crude, the global oil benchmark, fell 0.74% to $73.49 per barrel in futures trade.\n\nIn the domestic equity market, the 30-share BSE Sensex declined 1,414.33 points, or 1.90%, to settle at 73,198.10, while the Nifty fell 420.35 points, or 1.86%, to 22,124.70 points.",
#       "question": "Why is the price of Rupee depreciating"
#     }
#   ]
# }
# [llm/start] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain > chain:LLMChain > llm:OpenAI] Entering LLM run with input:
# {
#   "prompts": [
#     "Use the following portion of a long document to see if any of the text is relevant to answer the question. \nReturn any relevant text verbatim.\nReddit\n\nRemove SEE ALL\n\nFIIs offloaded equities worth ₹556.56 crore in the capital markets on net basis on Thursday (February 27, 2025), according to exchange data. File | Photo Credit: Reuters\n\nThe depreciated 28 paise to close at 87.46 (provisional) against the U.S. dollar on Friday (February 28, 2025), as the strength of the American currency and a negative trend in domestic equities dented investor sentiments.\n\nForex traders said the ongoing uncertainty surrounding tariff imposition by the U.S. has left financial markets in flux. Moreover, the tariff chaos has injected volatility and uncertainty into the U.S. Dollar Index.\n\nAt the interbank foreign exchange, the rupee opened at 87.32 against the greenback. During the session it fell to an intra-day low of 87.53 before ending the session at 87.46 (provisional) against the dollar, logging a loss of 28 paise from its previous close.\nQuestion: Why is the price of Rupee depreciating\nRelevant text, if any:"
#   ]
# }
# [llm/start] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain > chain:LLMChain > llm:OpenAI] Entering LLM run with input:
# {
#   "prompts": [
#     "Use the following portion of a long document to see if any of the text is relevant to answer the question. \nReturn any relevant text verbatim.\nToday's Cache Your download of the top 5 technology stories of the day.\n\nSEE ALL NEWSLETTERS\n\nVisual Story Brandhub\n\nFebruary 28, 2025e-Paper\n\nSearch for topics, people, articles...\n\nIndia World Movies Sport Data Health Opinion Science Business Premium\n\nVideos Podcast Photos Crossword Newsletter\n\nLit for Life The Huddle\n\nRupee falls 28 paise to close at 87.46 against U.S. dollar\n\nRupee depreciates against U.S. dollar due to strength of American currency, negative equities trend, and tariff uncertainty\n\nPublished - February 28, 2025 04:21 pm IST - Mumbai\n\nPTI\n\nCopy link\n\nEmail\n\nFacebook\n\nTwitter\n\nTelegram\n\nLinkedIn\n\nWhatsApp\n\nReddit\n\nRemove SEE ALL\n\nFIIs offloaded equities worth ₹556.56 crore in the capital markets on net basis on Thursday (February 27, 2025), according to exchange data. File | Photo Credit: Reuters\nQuestion: Why is the price of Rupee depreciating\nRelevant text, if any:"
#   ]
# }
# [llm/start] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain > chain:LLMChain > llm:OpenAI] Entering LLM run with input:
# {
#   "prompts": [
#     "Use the following portion of a long document to see if any of the text is relevant to answer the question. \nReturn any relevant text verbatim.\nIn the domestic equity market, the 30-share BSE Sensex declined 1,414.33 points, or 1.90%, to settle at 73,198.10, while the Nifty fell 420.35 points, or 1.86%, to 22,124.70 points.\n\nMeanwhile, the Reserve Bank of India (RBI) on Friday (February 28, 2025) conducted U.S. dollar-rupee swap worth $10 billion for injecting long term liquidity in the system, with the auction eliciting robust demand. The settlement of auction will take place on March 4 and March 6.\n\nUnder the swap exercise, a bank shall sell U.S. dollars to the RBI and simultaneously agree to buy the same amount of U.S. dollars at the end of the swap period.\n\nForeign Institutional Investors (FIIs) offloaded equities worth ₹556.56 crore in the capital markets on net basis on Thursday (February 27, 2025), according to exchange data.\nQuestion: Why is the price of Rupee depreciating\nRelevant text, if any:"
#   ]
# }
# [llm/start] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain > chain:LLMChain > llm:OpenAI] Entering LLM run with input:
# {
#   "prompts": [
#     "Use the following portion of a long document to see if any of the text is relevant to answer the question. \nReturn any relevant text verbatim.\nOn Thursday (February 27, 2025), the rupee settled almost flat with a marginal gain of 1 paisa at 87.18 against U.S. dollar.\n\nElevated greenback against major crosses and sustained FII outflows also contributed to the decline in the domestic unit, forex traders said.\n\nBesides, month-end dollar demand by importers amid uncertainty over U.S. trade tariffs also boosted the American currency.\n\nMeanwhile, the dollar index, which gauges the greenback’s strength against a basket of six currencies, was trading 0.08% higher at 107.33.\n\nBrent crude, the global oil benchmark, fell 0.74% to $73.49 per barrel in futures trade.\n\nIn the domestic equity market, the 30-share BSE Sensex declined 1,414.33 points, or 1.90%, to settle at 73,198.10, while the Nifty fell 420.35 points, or 1.86%, to 22,124.70 points.\nQuestion: Why is the price of Rupee depreciating\nRelevant text, if any:"
#   ]
# }
# [llm/end] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain > chain:LLMChain > llm:OpenAI] [1.94s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": " The depreciated 28 paise to close at 87.46 (provisional) against the U.S. dollar on Friday (February 28, 2025), as the strength of the American currency and a negative trend in domestic equities dented investor sentiments.",
#         "generation_info": {
#           "finish_reason": "stop",
#           "logprobs": null
#         },
#         "type": "Generation"
#       }
#     ]
#   ],
#   "llm_output": {
#     "token_usage": {
#       "prompt_tokens": 1031,
#       "total_tokens": 1213,
#       "completion_tokens": 182
#     },
#     "model_name": "gpt-3.5-turbo-instruct"
#   },
#   "run": null,
#   "type": "LLMResult"
# }
# [llm/end] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain > chain:LLMChain > llm:OpenAI] [1.94s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": " \n\"Rupee depreciates against U.S. dollar due to strength of American currency, negative equities trend, and tariff uncertainty\"",
#         "generation_info": {
#           "finish_reason": "stop",
#           "logprobs": null
#         },
#         "type": "Generation"
#       }
#     ]
#   ],
#   "llm_output": {
#     "token_usage": {},
#     "model_name": "gpt-3.5-turbo-instruct"
#   },
#   "run": null,
#   "type": "LLMResult"
# }
# [llm/end] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain > chain:LLMChain > llm:OpenAI] [1.94s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": " The Reserve Bank of India (RBI) on Friday (February 28, 2025) conducted U.S. dollar-rupee swap worth $10 billion for injecting long term liquidity in the system, with the auction eliciting robust demand.",
#         "generation_info": {
#           "finish_reason": "stop",
#           "logprobs": null
#         },
#         "type": "Generation"
#       }
#     ]
#   ],
#   "llm_output": {
#     "token_usage": {},
#     "model_name": "gpt-3.5-turbo-instruct"
#   },
#   "run": null,
#   "type": "LLMResult"
# }
# [llm/end] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain > chain:LLMChain > llm:OpenAI] [1.94s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": " Elevated greenback against major crosses and sustained FII outflows also contributed to the decline in the domestic unit, forex traders said. Besides, month-end dollar demand by importers amid uncertainty over U.S. trade tariffs also boosted the American currency.",
#         "generation_info": {
#           "finish_reason": "stop",
#           "logprobs": null
#         },
#         "type": "Generation"
#       }
#     ]
#   ],
#   "llm_output": {
#     "token_usage": {},
#     "model_name": "gpt-3.5-turbo-instruct"
#   },
#   "run": null,
#   "type": "LLMResult"
# }
# [chain/end] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain > chain:LLMChain] [1.94s] Exiting Chain run with output:
# {
#   "outputs": [
#     {
#       "text": " The depreciated 28 paise to close at 87.46 (provisional) against the U.S. dollar on Friday (February 28, 2025), as the strength of the American currency and a negative trend in domestic equities dented investor sentiments."
#     },
#     {
#       "text": " \n\"Rupee depreciates against U.S. dollar due to strength of American currency, negative equities trend, and tariff uncertainty\""
#     },
#     {
#       "text": " The Reserve Bank of India (RBI) on Friday (February 28, 2025) conducted U.S. dollar-rupee swap worth $10 billion for injecting long term liquidity in the system, with the auction eliciting robust demand."
#     },
#     {
#       "text": " Elevated greenback against major crosses and sustained FII outflows also contributed to the decline in the domestic unit, forex traders said. Besides, month-end dollar demand by importers amid uncertainty over U.S. trade tariffs also boosted the American currency."
#     }
#   ]
# }
# [chain/start] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain > chain:LLMChain] Entering Chain run with input:
# {
#   "question": "Why is the price of Rupee depreciating",
#   "summaries": "Content:  The depreciated 28 paise to close at 87.46 (provisional) against the U.S. dollar on Friday (February 28, 2025), as the strength of the American currency and a negative trend in domestic equities dented investor sentiments.\nSource:  https://www.thehindu.com/business/markets/rupee-falls-28-paise-to-close-at-8746-against-us-dollar/article69274471.ece\n\nContent:  \n\"Rupee depreciates against U.S. dollar due to strength of American currency, negative equities trend, and tariff uncertainty\"\nSource:  https://www.thehindu.com/business/markets/rupee-falls-28-paise-to-close-at-8746-against-us-dollar/article69274471.ece\n\nContent:  The Reserve Bank of India (RBI) on Friday (February 28, 2025) conducted U.S. dollar-rupee swap worth $10 billion for injecting long term liquidity in the system, with the auction eliciting robust demand.\nSource:  https://www.thehindu.com/business/markets/rupee-falls-28-paise-to-close-at-8746-against-us-dollar/article69274471.ece\n\nContent:  Elevated greenback against major crosses and sustained FII outflows also contributed to the decline in the domestic unit, forex traders said. Besides, month-end dollar demand by importers amid uncertainty over U.S. trade tariffs also boosted the American currency.\nSource:  https://www.thehindu.com/business/markets/rupee-falls-28-paise-to-close-at-8746-against-us-dollar/article69274471.ece"
# }
# [llm/start] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain > chain:LLMChain > llm:OpenAI] Entering LLM run with input:
# {
#   "prompts": [
#     "Given the following extracted parts of a long document and a question, create a final answer with references (\"SOURCES\"). \nIf you don't know the answer, just say that you don't know. Don't try to make up an answer.\nALWAYS return a \"SOURCES\" part in your answer.\n\nQUESTION: Which state/country's law governs the interpretation of the contract?\n=========\nContent: This Agreement is governed by English law and the parties submit to the exclusive jurisdiction of the English courts in  relation to any dispute (contractual or non-contractual) concerning this Agreement save that either party may apply to any court for an  injunction or other relief to protect its Intellectual Property Rights.\nSource: 28-pl\nContent: No Waiver. Failure or delay in exercising any right or remedy under this Agreement shall not constitute a waiver of such (or any other)  right or remedy.\n\n11.7 Severability. The invalidity, illegality or unenforceability of any term (or part of a term) of this Agreement shall not affect the continuation  in force of the remainder of the term (if any) and this Agreement.\n\n11.8 No Agency. Except as expressly stated otherwise, nothing in this Agreement shall create an agency, partnership or joint venture of any  kind between the parties.\n\n11.9 No Third-Party Beneficiaries.\nSource: 30-pl\nContent: (b) if Google believes, in good faith, that the Distributor has violated or caused Google to violate any Anti-Bribery Laws (as  defined in Clause 8.5) or that such a violation is reasonably likely to occur,\nSource: 4-pl\n=========\nFINAL ANSWER: This Agreement is governed by English law.\nSOURCES: 28-pl\n\nQUESTION: What did the president say about Michael Jackson?\n=========\nContent: Madam Speaker, Madam Vice President, our First Lady and Second Gentleman. Members of Congress and the Cabinet. Justices of the Supreme Court. My fellow Americans.  \n\nLast year COVID-19 kept us apart. This year we are finally together again. \n\nTonight, we meet as Democrats Republicans and Independents. But most importantly as Americans. \n\nWith a duty to one another to the American people to the Constitution. \n\nAnd with an unwavering resolve that freedom will always triumph over tyranny. \n\nSix days ago, Russia’s Vladimir Putin sought to shake the foundations of the free world thinking he could make it bend to his menacing ways. But he badly miscalculated. \n\nHe thought he could roll into Ukraine and the world would roll over. Instead he met a wall of strength he never imagined. \n\nHe met the Ukrainian people. \n\nFrom President Zelenskyy to every Ukrainian, their fearlessness, their courage, their determination, inspires the world. \n\nGroups of citizens blocking tanks with their bodies. Everyone from students to retirees teachers turned soldiers defending their homeland.\nSource: 0-pl\nContent: And we won’t stop. \n\nWe have lost so much to COVID-19. Time with one another. And worst of all, so much loss of life. \n\nLet’s use this moment to reset. Let’s stop looking at COVID-19 as a partisan dividing line and see it for what it is: A God-awful disease.  \n\nLet’s stop seeing each other as enemies, and start seeing each other for who we really are: Fellow Americans.  \n\nWe can’t change how divided we’ve been. But we can change how we move forward—on COVID-19 and other issues we must face together. \n\nI recently visited the New York City Police Department days after the funerals of Officer Wilbert Mora and his partner, Officer Jason Rivera. \n\nThey were responding to a 9-1-1 call when a man shot and killed them with a stolen gun. \n\nOfficer Mora was 27 years old. \n\nOfficer Rivera was 22. \n\nBoth Dominican Americans who’d grown up on the same streets they later chose to patrol as police officers. \n\nI spoke with their families and told them that we are forever in debt for their sacrifice, and we will carry on their mission to restore the trust and safety every community deserves.\nSource: 24-pl\nContent: And a prou ...
#   ]
# }
# [llm/end] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain > chain:LLMChain > llm:OpenAI] [1.43s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": " The price of Rupee may be depreciating due to the strength of the American currency, negative trends in domestic equities, uncertainty over U.S. trade tariffs, and sustained FII outflows.\nSOURCES: https://www.thehindu.com/business/markets/rupee-falls-28-paise-to-close-at-8746-against-us-dollar/article69274471.ece",
#         "generation_info": {
#           "finish_reason": "stop",
#           "logprobs": null
#         },
#         "type": "Generation"
#       }
#     ]
#   ],
#   "llm_output": {
#     "token_usage": {
#       "prompt_tokens": 1700,
#       "total_tokens": 1778,
#       "completion_tokens": 78
#     },
#     "model_name": "gpt-3.5-turbo-instruct"
#   },
#   "run": null,
#   "type": "LLMResult"
# }
# [chain/end] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain > chain:LLMChain] [1.43s] Exiting Chain run with output:
# {
#   "text": " The price of Rupee may be depreciating due to the strength of the American currency, negative trends in domestic equities, uncertainty over U.S. trade tariffs, and sustained FII outflows.\nSOURCES: https://www.thehindu.com/business/markets/rupee-falls-28-paise-to-close-at-8746-against-us-dollar/article69274471.ece"
# }
# [chain/end] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain] [3.38s] Exiting Chain run with output:
# {
#   "output_text": " The price of Rupee may be depreciating due to the strength of the American currency, negative trends in domestic equities, uncertainty over U.S. trade tariffs, and sustained FII outflows.\nSOURCES: https://www.thehindu.com/business/markets/rupee-falls-28-paise-to-close-at-8746-against-us-dollar/article69274471.ece"
# }
# [chain/end] [chain:RetrievalQAWithSourcesChain] [3.87s] Exiting Chain run with output:
# {
#   "answer": " The price of Rupee may be depreciating due to the strength of the American currency, negative trends in domestic equities, uncertainty over U.S. trade tariffs, and sustained FII outflows.\n",
#   "sources": "https://www.thehindu.com/business/markets/rupee-falls-28-paise-to-close-at-8746-against-us-dollar/article69274471.ece"
# }
# {'answer': ' The price of Rupee may be depreciating due to the strength of the American currency, negative trends in domestic equities, uncertainty over U.S. trade tariffs, and sustained FII outflows.\n',
#  'sources': 'https://www.thehindu.com/business/markets/rupee-falls-28-paise-to-close-at-8746-against-us-dollar/article69274471.ece'}

# %%
query = "Can you summarize on the stocks that are hitting 52 week high"
#langchain.debug=True

q_a_chain({"question":query}, return_only_outputs=True)
# Out:
# [chain/start] [chain:RetrievalQAWithSourcesChain] Entering Chain run with input:
# {
#   "question": "Can you summarize on the stocks that are hitting 52 week high"
# }
# [chain/start] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain] Entering Chain run with input:
# [inputs]
# [chain/start] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain > chain:LLMChain] Entering Chain run with input:
# {
#   "input_list": [
#     {
#       "context": "Meanwhile, stocks such as Photon Capital, Hira Automobiles, Aris Intnl, Dhanlaxmi Cotex and Triumph International Finance India Ltd. hit their fresh 52-week high, while Cosyn, Capital Trust, Envair Electro, Kunststoffe Ind and Nova Iron Steel touched their new 52-week low in today's trade.\n\nStock Trading\n\nMaximise Returns by Investing in the Right Companies\n\nBy - The Economic Times, Get Certified By India's Top Business News Brand\n\nStock Trading\n\nRenko Chart Patterns Made Easy\n\nBy - Kaushik Akiwatkar, Derivative Trader and Investor\n\nStock Trading\n\nCandlesticks Made Easy: Candlestick Pattern Course\n\nBy - elearnmarkets, Financial Education by StockEdge\n\nStock Trading\n\nDow Theory Made Easy\n\nBy - Vishal Mehta, Independent Systematic Trader\n\nStock Trading\n\nMarket 101: An Insight into Trendlines and Momentum\n\nBy - Rohit Srivastava, Founder- Indiacharts.com\n\nStock Trading\n\nMarkets 102: Mastering Sentiment Indicators for Swing and Positional Trading",
#       "question": "Can you summarize on the stocks that are hitting 52 week high"
#     },
#     {
#       "context": "Benchmarks\n\nNifty22,124.70-420.35\n\nFEATURED FUNDS\n\n★★★★★\n\nHSBC Large Cap Fund Direct-Growth\n\n5Y Return\n\n15.12 %\n\nInvest Now\n\nFEATURED FUNDS\n\n★★★★★\n\nCanara Robeco ELSS Tax Saver Regular - Growth\n\n5Y Return\n\n16.38 %\n\nInvest Now\n\nEnglish EditionEnglish Editionहिन्दीગુજરાતીमराठीবাংলাಕನ್ನಡമലയാളംதமிழ்తెలుగు\n\n| Today's ePaper\n\nMy Watchlist Subscribe\n\nSign In\n\nBusiness News›Markets›Stocks›Stock Watch›Stock market update: Stocks that hit 52-week highs on NSE in today's trade\n\nThe Economic Times daily newspaper is available online now.\n\nRead Today's Paper\n\nStock market update: Stocks that hit 52-week highs on NSE in today's trade\n\nSECTIONS\n\nStock market update: Stocks that hit 52-week highs on NSE in today's trade\n\nETMarkets.comLast Updated: Feb 28, 2025, 05:17:00 PM IST\n\nRate Story\n\nFollow us\n\nShare\n\nFont Size\n\nAbcSmall\n\nAbcMedium\n\nAbcLarge\n\nSave\n\nPrint\n\nComment\n\nSynopsis",
#       "question": "Can you summarize on the stocks that are hitting 52 week high"
#     },
#     {
#       "context": "ETMarkets.comLast Updated: Feb 28, 2025, 05:17:00 PM IST\n\nRate Story\n\nFollow us\n\nShare\n\nFont Size\n\nAbcSmall\n\nAbcMedium\n\nAbcLarge\n\nSave\n\nPrint\n\nComment\n\nSynopsis\n\nBrookfield India REIT, Blue Coast Hotel, Norben Tea Exp, Capital Infra Trust and Laxmi Goldorna House, hit their fresh 52-week highs during the day.\n\nNEW DELHI: Shares of Brookfield India REIT, Blue Coast Hotel, Norben Tea Exp, Capital Infra Trust and Laxmi Goldorna House, hit their fresh 52-week highs during Friday's trade on NSE. Benchmark NSE Nifty closed 420.35 points down at 22124.7 amid selling in frontline bluechip counters.\n\nHowever, stocks such as Cyber Media Ltd, TBO Tek, Williamson Magor, IndiaPowerCorp and 8K Miles Soft, touched their fresh 52-week lows. Overall, 5 shares ended in the green in Nifty50 index, while 44 closed in the red.",
#       "question": "Can you summarize on the stocks that are hitting 52 week high"
#     },
#     {
#       "context": "Follow us\n\nShare\n\nFont Size\n\nAbcSmall\n\nAbcMedium\n\nAbcLarge\n\nSave\n\nPrint\n\nComment\n\nSynopsis\n\nIn the Nifty 50 index, 5 stocks ended in the green, while 44 stocks closed in the red in today's trade.\n\nNEW DELHI: A number of stocks rose in excess of 10% on BSE as domestic equity indices, BSE Sensex and NSE Nifty, ended in the red on Friday. These high-performing stocks that rallied more than 10% during the session included, Medico Remedies(11.81%), Home First Finance Co(11.56%) and Transpact Enterprise(10.00%).\n\nThe 30-share Sensex ended 1414.33 points down at 73198.1, while the 50-share Nifty index closed 420.35 points down at 22124.7. In the Nifty 50 index, 5 stocks ended in the green, while 44 stocks closed in the red.",
#       "question": "Can you summarize on the stocks that are hitting 52 week high"
#     }
#   ]
# }
# [llm/start] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain > chain:LLMChain > llm:OpenAI] Entering LLM run with input:
# {
#   "prompts": [
#     "Use the following portion of a long document to see if any of the text is relevant to answer the question. \nReturn any relevant text verbatim.\nMeanwhile, stocks such as Photon Capital, Hira Automobiles, Aris Intnl, Dhanlaxmi Cotex and Triumph International Finance India Ltd. hit their fresh 52-week high, while Cosyn, Capital Trust, Envair Electro, Kunststoffe Ind and Nova Iron Steel touched their new 52-week low in today's trade.\n\nStock Trading\n\nMaximise Returns by Investing in the Right Companies\n\nBy - The Economic Times, Get Certified By India's Top Business News Brand\n\nStock Trading\n\nRenko Chart Patterns Made Easy\n\nBy - Kaushik Akiwatkar, Derivative Trader and Investor\n\nStock Trading\n\nCandlesticks Made Easy: Candlestick Pattern Course\n\nBy - elearnmarkets, Financial Education by StockEdge\n\nStock Trading\n\nDow Theory Made Easy\n\nBy - Vishal Mehta, Independent Systematic Trader\n\nStock Trading\n\nMarket 101: An Insight into Trendlines and Momentum\n\nBy - Rohit Srivastava, Founder- Indiacharts.com\n\nStock Trading\n\nMarkets 102: Mastering Sentiment Indicators for Swing and Positional Trading\nQuestion: Can you summarize on the stocks that are hitting 52 week high\nRelevant text, if any:"
#   ]
# }
# [llm/start] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain > chain:LLMChain > llm:OpenAI] Entering LLM run with input:
# {
#   "prompts": [
#     "Use the following portion of a long document to see if any of the text is relevant to answer the question. \nReturn any relevant text verbatim.\nBenchmarks\n\nNifty22,124.70-420.35\n\nFEATURED FUNDS\n\n★★★★★\n\nHSBC Large Cap Fund Direct-Growth\n\n5Y Return\n\n15.12 %\n\nInvest Now\n\nFEATURED FUNDS\n\n★★★★★\n\nCanara Robeco ELSS Tax Saver Regular - Growth\n\n5Y Return\n\n16.38 %\n\nInvest Now\n\nEnglish EditionEnglish Editionहिन्दीગુજરાતીमराठीবাংলাಕನ್ನಡമലയാളംதமிழ்తెలుగు\n\n| Today's ePaper\n\nMy Watchlist Subscribe\n\nSign In\n\nBusiness News›Markets›Stocks›Stock Watch›Stock market update: Stocks that hit 52-week highs on NSE in today's trade\n\nThe Economic Times daily newspaper is available online now.\n\nRead Today's Paper\n\nStock market update: Stocks that hit 52-week highs on NSE in today's trade\n\nSECTIONS\n\nStock market update: Stocks that hit 52-week highs on NSE in today's trade\n\nETMarkets.comLast Updated: Feb 28, 2025, 05:17:00 PM IST\n\nRate Story\n\nFollow us\n\nShare\n\nFont Size\n\nAbcSmall\n\nAbcMedium\n\nAbcLarge\n\nSave\n\nPrint\n\nComment\n\nSynopsis\nQuestion: Can you summarize on the stocks that are hitting 52 week high\nRelevant text, if any:"
#   ]
# }
# [llm/start] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain > chain:LLMChain > llm:OpenAI] Entering LLM run with input:
# {
#   "prompts": [
#     "Use the following portion of a long document to see if any of the text is relevant to answer the question. \nReturn any relevant text verbatim.\nETMarkets.comLast Updated: Feb 28, 2025, 05:17:00 PM IST\n\nRate Story\n\nFollow us\n\nShare\n\nFont Size\n\nAbcSmall\n\nAbcMedium\n\nAbcLarge\n\nSave\n\nPrint\n\nComment\n\nSynopsis\n\nBrookfield India REIT, Blue Coast Hotel, Norben Tea Exp, Capital Infra Trust and Laxmi Goldorna House, hit their fresh 52-week highs during the day.\n\nNEW DELHI: Shares of Brookfield India REIT, Blue Coast Hotel, Norben Tea Exp, Capital Infra Trust and Laxmi Goldorna House, hit their fresh 52-week highs during Friday's trade on NSE. Benchmark NSE Nifty closed 420.35 points down at 22124.7 amid selling in frontline bluechip counters.\n\nHowever, stocks such as Cyber Media Ltd, TBO Tek, Williamson Magor, IndiaPowerCorp and 8K Miles Soft, touched their fresh 52-week lows. Overall, 5 shares ended in the green in Nifty50 index, while 44 closed in the red.\nQuestion: Can you summarize on the stocks that are hitting 52 week high\nRelevant text, if any:"
#   ]
# }
# [llm/start] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain > chain:LLMChain > llm:OpenAI] Entering LLM run with input:
# {
#   "prompts": [
#     "Use the following portion of a long document to see if any of the text is relevant to answer the question. \nReturn any relevant text verbatim.\nFollow us\n\nShare\n\nFont Size\n\nAbcSmall\n\nAbcMedium\n\nAbcLarge\n\nSave\n\nPrint\n\nComment\n\nSynopsis\n\nIn the Nifty 50 index, 5 stocks ended in the green, while 44 stocks closed in the red in today's trade.\n\nNEW DELHI: A number of stocks rose in excess of 10% on BSE as domestic equity indices, BSE Sensex and NSE Nifty, ended in the red on Friday. These high-performing stocks that rallied more than 10% during the session included, Medico Remedies(11.81%), Home First Finance Co(11.56%) and Transpact Enterprise(10.00%).\n\nThe 30-share Sensex ended 1414.33 points down at 73198.1, while the 50-share Nifty index closed 420.35 points down at 22124.7. In the Nifty 50 index, 5 stocks ended in the green, while 44 stocks closed in the red.\nQuestion: Can you summarize on the stocks that are hitting 52 week high\nRelevant text, if any:"
#   ]
# }
# [llm/end] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain > chain:LLMChain > llm:OpenAI] [1.81s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": " Meanwhile, stocks such as Photon Capital, Hira Automobiles, Aris Intnl, Dhanlaxmi Cotex and Triumph International Finance India Ltd. hit their fresh 52-week high in today's trade.",
#         "generation_info": {
#           "finish_reason": "stop",
#           "logprobs": null
#         },
#         "type": "Generation"
#       }
#     ]
#   ],
#   "llm_output": {
#     "token_usage": {
#       "prompt_tokens": 1187,
#       "total_tokens": 1376,
#       "completion_tokens": 189
#     },
#     "model_name": "gpt-3.5-turbo-instruct"
#   },
#   "run": null,
#   "type": "LLMResult"
# }
# [llm/end] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain > chain:LLMChain > llm:OpenAI] [1.81s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": " \"Stock market update: Stocks that hit 52-week highs on NSE in today's trade\"",
#         "generation_info": {
#           "finish_reason": "stop",
#           "logprobs": null
#         },
#         "type": "Generation"
#       }
#     ]
#   ],
#   "llm_output": {
#     "token_usage": {},
#     "model_name": "gpt-3.5-turbo-instruct"
#   },
#   "run": null,
#   "type": "LLMResult"
# }
# [llm/end] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain > chain:LLMChain > llm:OpenAI] [1.81s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": " Shares of Brookfield India REIT, Blue Coast Hotel, Norben Tea Exp, Capital Infra Trust and Laxmi Goldorna House, hit their fresh 52-week highs during Friday's trade on NSE.",
#         "generation_info": {
#           "finish_reason": "stop",
#           "logprobs": null
#         },
#         "type": "Generation"
#       }
#     ]
#   ],
#   "llm_output": {
#     "token_usage": {},
#     "model_name": "gpt-3.5-turbo-instruct"
#   },
#   "run": null,
#   "type": "LLMResult"
# }
# [llm/end] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain > chain:LLMChain > llm:OpenAI] [1.81s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": " A number of stocks rose in excess of 10% on BSE as domestic equity indices, BSE Sensex and NSE Nifty, ended in the red on Friday. These high-performing stocks that rallied more than 10% during the session included, Medico Remedies(11.81%), Home First Finance Co(11.56%) and Transpact Enterprise(10.00%).",
#         "generation_info": {
#           "finish_reason": "stop",
#           "logprobs": null
#         },
#         "type": "Generation"
#       }
#     ]
#   ],
#   "llm_output": {
#     "token_usage": {},
#     "model_name": "gpt-3.5-turbo-instruct"
#   },
#   "run": null,
#   "type": "LLMResult"
# }
# [chain/end] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain > chain:LLMChain] [1.81s] Exiting Chain run with output:
# {
#   "outputs": [
#     {
#       "text": " Meanwhile, stocks such as Photon Capital, Hira Automobiles, Aris Intnl, Dhanlaxmi Cotex and Triumph International Finance India Ltd. hit their fresh 52-week high in today's trade."
#     },
#     {
#       "text": " \"Stock market update: Stocks that hit 52-week highs on NSE in today's trade\""
#     },
#     {
#       "text": " Shares of Brookfield India REIT, Blue Coast Hotel, Norben Tea Exp, Capital Infra Trust and Laxmi Goldorna House, hit their fresh 52-week highs during Friday's trade on NSE."
#     },
#     {
#       "text": " A number of stocks rose in excess of 10% on BSE as domestic equity indices, BSE Sensex and NSE Nifty, ended in the red on Friday. These high-performing stocks that rallied more than 10% during the session included, Medico Remedies(11.81%), Home First Finance Co(11.56%) and Transpact Enterprise(10.00%)."
#     }
#   ]
# }
# [chain/start] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain > chain:LLMChain] Entering Chain run with input:
# {
#   "question": "Can you summarize on the stocks that are hitting 52 week high",
#   "summaries": "Content:  Meanwhile, stocks such as Photon Capital, Hira Automobiles, Aris Intnl, Dhanlaxmi Cotex and Triumph International Finance India Ltd. hit their fresh 52-week high in today's trade.\nSource:  https://economictimes.indiatimes.com/markets/stocks/stock-watch/sensex-falls-but-these-stocks-gained-over-10-on-bse/articleshow/118628952.cms\n\nContent:  \"Stock market update: Stocks that hit 52-week highs on NSE in today's trade\"\nSource:  https://economictimes.indiatimes.com/markets/stocks/stock-watch/stock-market-update-stocks-that-hit-52-week-highs-on-nse-in-todays-trade/articleshow/118628856.cms\n\nContent:  Shares of Brookfield India REIT, Blue Coast Hotel, Norben Tea Exp, Capital Infra Trust and Laxmi Goldorna House, hit their fresh 52-week highs during Friday's trade on NSE.\nSource:  https://economictimes.indiatimes.com/markets/stocks/stock-watch/stock-market-update-stocks-that-hit-52-week-highs-on-nse-in-todays-trade/articleshow/118628856.cms\n\nContent:  A number of stocks rose in excess of 10% on BSE as domestic equity indices, BSE Sensex and NSE Nifty, ended in the red on Friday. These high-performing stocks that rallied more than 10% during the session included, Medico Remedies(11.81%), Home First Finance Co(11.56%) and Transpact Enterprise(10.00%).\nSource:  https://economictimes.indiatimes.com/markets/stocks/stock-watch/sensex-falls-but-these-stocks-gained-over-10-on-bse/articleshow/118628952.cms"
# }
# [llm/start] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain > chain:LLMChain > llm:OpenAI] Entering LLM run with input:
# {
#   "prompts": [
#     "Given the following extracted parts of a long document and a question, create a final answer with references (\"SOURCES\"). \nIf you don't know the answer, just say that you don't know. Don't try to make up an answer.\nALWAYS return a \"SOURCES\" part in your answer.\n\nQUESTION: Which state/country's law governs the interpretation of the contract?\n=========\nContent: This Agreement is governed by English law and the parties submit to the exclusive jurisdiction of the English courts in  relation to any dispute (contractual or non-contractual) concerning this Agreement save that either party may apply to any court for an  injunction or other relief to protect its Intellectual Property Rights.\nSource: 28-pl\nContent: No Waiver. Failure or delay in exercising any right or remedy under this Agreement shall not constitute a waiver of such (or any other)  right or remedy.\n\n11.7 Severability. The invalidity, illegality or unenforceability of any term (or part of a term) of this Agreement shall not affect the continuation  in force of the remainder of the term (if any) and this Agreement.\n\n11.8 No Agency. Except as expressly stated otherwise, nothing in this Agreement shall create an agency, partnership or joint venture of any  kind between the parties.\n\n11.9 No Third-Party Beneficiaries.\nSource: 30-pl\nContent: (b) if Google believes, in good faith, that the Distributor has violated or caused Google to violate any Anti-Bribery Laws (as  defined in Clause 8.5) or that such a violation is reasonably likely to occur,\nSource: 4-pl\n=========\nFINAL ANSWER: This Agreement is governed by English law.\nSOURCES: 28-pl\n\nQUESTION: What did the president say about Michael Jackson?\n=========\nContent: Madam Speaker, Madam Vice President, our First Lady and Second Gentleman. Members of Congress and the Cabinet. Justices of the Supreme Court. My fellow Americans.  \n\nLast year COVID-19 kept us apart. This year we are finally together again. \n\nTonight, we meet as Democrats Republicans and Independents. But most importantly as Americans. \n\nWith a duty to one another to the American people to the Constitution. \n\nAnd with an unwavering resolve that freedom will always triumph over tyranny. \n\nSix days ago, Russia’s Vladimir Putin sought to shake the foundations of the free world thinking he could make it bend to his menacing ways. But he badly miscalculated. \n\nHe thought he could roll into Ukraine and the world would roll over. Instead he met a wall of strength he never imagined. \n\nHe met the Ukrainian people. \n\nFrom President Zelenskyy to every Ukrainian, their fearlessness, their courage, their determination, inspires the world. \n\nGroups of citizens blocking tanks with their bodies. Everyone from students to retirees teachers turned soldiers defending their homeland.\nSource: 0-pl\nContent: And we won’t stop. \n\nWe have lost so much to COVID-19. Time with one another. And worst of all, so much loss of life. \n\nLet’s use this moment to reset. Let’s stop looking at COVID-19 as a partisan dividing line and see it for what it is: A God-awful disease.  \n\nLet’s stop seeing each other as enemies, and start seeing each other for who we really are: Fellow Americans.  \n\nWe can’t change how divided we’ve been. But we can change how we move forward—on COVID-19 and other issues we must face together. \n\nI recently visited the New York City Police Department days after the funerals of Officer Wilbert Mora and his partner, Officer Jason Rivera. \n\nThey were responding to a 9-1-1 call when a man shot and killed them with a stolen gun. \n\nOfficer Mora was 27 years old. \n\nOfficer Rivera was 22. \n\nBoth Dominican Americans who’d grown up on the same streets they later chose to patrol as police officers. \n\nI spoke with their families and told them that we are forever in debt for their sacrifice, and we will carry on their mission to restore the trust and safety every community deserves.\nSource: 24-pl\nContent: And a prou ...
#   ]
# }
# [llm/end] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain > chain:LLMChain > llm:OpenAI] [2.57s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": " Stocks hitting their fresh 52-week high in today's trade include Photon Capital, Hira Automobiles, Aris Intnl, Dhanlaxmi Cotex, Triumph International Finance India Ltd., Brookfield India REIT, Blue Coast Hotel, Norben Tea Exp, Capital Infra Trust, Laxmi Goldorna House, Medico Remedies, Home First Finance Co, and Transpact Enterprise.\nSOURCES: https://economictimes.indiatimes.com/markets/stocks/stock-watch/sensex-falls-but-these-stocks-gained-over-10-on-bse/articleshow/118628952.cms, https://economictimes.indiatimes.com/markets/stocks/stock-watch/stock-market-update-stocks-that-hit-52-week-highs-on-nse-in-todays-trade/articleshow/118628856.cms",
#         "generation_info": {
#           "finish_reason": "stop",
#           "logprobs": null
#         },
#         "type": "Generation"
#       }
#     ]
#   ],
#   "llm_output": {
#     "token_usage": {
#       "prompt_tokens": 1745,
#       "total_tokens": 1918,
#       "completion_tokens": 173
#     },
#     "model_name": "gpt-3.5-turbo-instruct"
#   },
#   "run": null,
#   "type": "LLMResult"
# }
# [chain/end] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain > chain:LLMChain] [2.57s] Exiting Chain run with output:
# {
#   "text": " Stocks hitting their fresh 52-week high in today's trade include Photon Capital, Hira Automobiles, Aris Intnl, Dhanlaxmi Cotex, Triumph International Finance India Ltd., Brookfield India REIT, Blue Coast Hotel, Norben Tea Exp, Capital Infra Trust, Laxmi Goldorna House, Medico Remedies, Home First Finance Co, and Transpact Enterprise.\nSOURCES: https://economictimes.indiatimes.com/markets/stocks/stock-watch/sensex-falls-but-these-stocks-gained-over-10-on-bse/articleshow/118628952.cms, https://economictimes.indiatimes.com/markets/stocks/stock-watch/stock-market-update-stocks-that-hit-52-week-highs-on-nse-in-todays-trade/articleshow/118628856.cms"
# }
# [chain/end] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain] [4.39s] Exiting Chain run with output:
# {
#   "output_text": " Stocks hitting their fresh 52-week high in today's trade include Photon Capital, Hira Automobiles, Aris Intnl, Dhanlaxmi Cotex, Triumph International Finance India Ltd., Brookfield India REIT, Blue Coast Hotel, Norben Tea Exp, Capital Infra Trust, Laxmi Goldorna House, Medico Remedies, Home First Finance Co, and Transpact Enterprise.\nSOURCES: https://economictimes.indiatimes.com/markets/stocks/stock-watch/sensex-falls-but-these-stocks-gained-over-10-on-bse/articleshow/118628952.cms, https://economictimes.indiatimes.com/markets/stocks/stock-watch/stock-market-update-stocks-that-hit-52-week-highs-on-nse-in-todays-trade/articleshow/118628856.cms"
# }
# [chain/end] [chain:RetrievalQAWithSourcesChain] [4.86s] Exiting Chain run with output:
# {
#   "answer": " Stocks hitting their fresh 52-week high in today's trade include Photon Capital, Hira Automobiles, Aris Intnl, Dhanlaxmi Cotex, Triumph International Finance India Ltd., Brookfield India REIT, Blue Coast Hotel, Norben Tea Exp, Capital Infra Trust, Laxmi Goldorna House, Medico Remedies, Home First Finance Co, and Transpact Enterprise.\n",
#   "sources": "https://economictimes.indiatimes.com/markets/stocks/stock-watch/sensex-falls-but-these-stocks-gained-over-10-on-bse/articleshow/118628952.cms, https://economictimes.indiatimes.com/markets/stocks/stock-watch/stock-market-update-stocks-that-hit-52-week-highs-on-nse-in-todays-trade/articleshow/118628856.cms"
# }
# {'answer': " Stocks hitting their fresh 52-week high in today's trade include Photon Capital, Hira Automobiles, Aris Intnl, Dhanlaxmi Cotex, Triumph International Finance India Ltd., Brookfield India REIT, Blue Coast Hotel, Norben Tea Exp, Capital Infra Trust, Laxmi Goldorna House, Medico Remedies, Home First Finance Co, and Transpact Enterprise.\n",
#  'sources': 'https://economictimes.indiatimes.com/markets/stocks/stock-watch/sensex-falls-but-these-stocks-gained-over-10-on-bse/articleshow/118628952.cms, https://economictimes.indiatimes.com/markets/stocks/stock-watch/stock-market-update-stocks-that-hit-52-week-highs-on-nse-in-todays-trade/articleshow/118628856.cms'}
